# %% [markdown]
# Task 3 notes:
# We use task 2 implementation (not task 1 as stated in the instructions)
# We took "inspiration" from "https://github.com/wiseodd/generative-models/blob/master/GAN/conditional_gan/cgan_pytorch.py" where everything is basically updated for us.
# We update G(z) and D(x) to become G(z,c) by adding inputs = torch.cat([z, c], 1)
# We load in the data differently than the reference.
# We also have to adjust the size of the weight and bias matrices for wxh and wyh.
# 1024 h_dim was too much. d_loss went to 0.0 and didn't converge.
# 256 h_dim may be too big.

# %%
print("test")
# Out:
# test

# %%
#task 1 GPU accelerated
from comet_ml import Experiment
import torch
import torch.nn.functional as nn
import torch.autograd as autograd
import torch.optim as optim
import numpy as np
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import os

from datetime import datetime




#GPU ACCELERATION
print("start")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
#GPU ACCELERATION


mb_size = 64 #mini batch size should be able raise to around 1024 for better performance
#!!!Task 3
c_dim = 10

mnist = datasets.MNIST( #had to be replaced from the old tensorflow implementation
    root='./MNIST_data',
    train=True,
    download=True,
    transform=transforms.ToTensor()
)
#dataloader
data_loader = torch.utils.data.DataLoader(mnist, batch_size=mb_size, shuffle=True)
print(mnist)
X_dim = mnist[0][0].numel() #should be 28 * 28 = 784
y_dim = len(mnist.classes) #should be 10 (0->9)
Z_dim = 100 #random seed? size of latent space vector z that is input to the image generator
h_dim = 256 #hidden layer width
lr = 1e-3 #learning rate gamma 
ones_label = torch.ones(mb_size, 1)   
zeros_label = torch.zeros(mb_size, 1) #batch size big vector of 0



def xavier_init(size): #xavier intialisation of weights for the network. Variance = (1/I_n + O_n)
    in_dim = size[0] #neurons of input layer
    xavier_stddev = 1. / np.sqrt(in_dim / 2.) #actual creation of the weights
    return torch.randn(size) * xavier_stddev #changed to not use "variable()"
#Generator non gpu accelerated
#Wzh = torch.nn.Parameter(xavier_init(size=[Z_dim, h_dim])) #input(z) -> hidden layer weigth intialisation (100 * 128)
#bzh = torch.nn.Parameter(torch.zeros(h_dim)) #changed to not use "variable()" #bias = 0
#Whx = torch.nn.Parameter(xavier_init(size=[h_dim, X_dim])) #hidden -> image(x) weigth intialisation (128 * 784)
#bhx = torch.nn.Parameter(torch.zeros(X_dim))#changed to not use "variable()"#bias = 0

#Generator GPU accelerated
Wzh = torch.nn.Parameter(xavier_init(size=[Z_dim+c_dim, h_dim]).to(device))
bzh = torch.nn.Parameter(torch.zeros(h_dim).to(device))
Whx = torch.nn.Parameter(xavier_init(size=[h_dim, X_dim]).to(device))
bhx = torch.nn.Parameter(torch.zeros(X_dim).to(device))
#!!!!Task 3
def G(z, c):
    inputs = torch.cat([z, c], 1)# z + c (100) + (10)
    h = nn.relu(inputs @ Wzh + bzh.repeat(inputs.size(0), 1)) #input(z + c) -> hidden layer pass
    X = nn.sigmoid(h @ Whx + bhx.repeat(h.size(0), 1))
    return X
#!!!!Task 3
#def G(z): #generator forward pass
#    h = nn.relu(z @ Wzh + bzh.repeat(z.size(0), 1)) #input(z) -> hidden layer pass
#    X = nn.sigmoid(h @ Whx + bhx.repeat(h.size(0), 1)) #hidden layer -> image pass
#    return X #image

def reset_grad():
    for p in params:
        if p.grad is not None:#added this to avoid crashing. p.grad can be None
            p.grad.zero_()

#Discriminator non gpu accelerated
#Wxh = torch.nn.Parameter(xavier_init(size=[X_dim, h_dim])) #image(x) -> hidden layer weight initialisation (748 * 128)
#bxh = torch.nn.Parameter(torch.zeros(h_dim)) #bias = 0
#Why = torch.nn.Parameter(xavier_init(size=[h_dim, 1])) #hidden layer -> output(y) layer weight initialisation(128 * 1)
#bhy = torch.nn.Parameter(torch.zeros(1))

#Discriminator GPU accelerated
Wxh = torch.nn.Parameter(xavier_init(size=[X_dim + c_dim, h_dim]).to(device))
bxh = torch.nn.Parameter(torch.zeros(h_dim).to(device))
Why = torch.nn.Parameter(xavier_init(size=[h_dim, 1]).to(device))
bhy = torch.nn.Parameter(torch.zeros(1).to(device))

#def D(X): #discriminator forward pass
#    h = nn.relu(X @ Wxh + bxh.repeat(X.size(0), 1)) #image(x) -> hidden layer pass
#    #!!!!Task2
#    y = h @ Why + bhy.repeat(h.size(0), 1)#image(x) -> hidden layer pass (real Logits)
#    #!!!!Task2
#    return y #output(real=1/fake=0)
    
#!!!!Task 3
def D(X, c):
    inputs = torch.cat([X, c], 1)# X + c (784) + (10) 
    h = nn.relu(inputs @ Wxh + bxh.repeat(inputs.size(0), 1)) #image(x + c) -> hidden layer pass
    #!!!!Task2
    y = h @ Why + bhy.repeat(h.size(0), 1)
    #!!!!Task2
    return y
#!!!!Task 3

G_params = [Wzh, bzh, Whx, bhx]#define generator parameters (pyTorch needs it like this)
D_params = [Wxh, bxh, Why, bhy] #define discriminator parameters (pyTorch needs it like this)
 
params = G_params + D_params

G_solver = optim.Adam(G_params, lr=1e-3) #Adaptive Moment Estimation(different learning rate per parameter + momentum)
D_solver = optim.Adam(D_params, lr=1e-3) #Adaptive Moment Estimation(different learning rate per parameter + momentum)
# Out:
# start
# Using device: cuda
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./MNIST_data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
#Task 1 training GPU accelerated:
run_name = datetime.now().strftime("Task3-%Y%m%d-%H%M%S")
#training
epochs = 500
experiment = Experiment(
    api_key="lZ6VM5qo8Rz8JKYXjXVS3zWzs",
    project_name="D7047E/Lab2",
    experiment_name=run_name  #
)
experiment.set_name(run_name)
experiment.log_parameters({
    "batch_size": mb_size,
    "Z_dim": Z_dim,
    "h_dim": h_dim,
    "learning_rate": lr,
    "epochs": epochs,
    "optimizer": "Adam",
    "loss_function": "nn.binary_cross_entropy_with_logits"
})

for epoch in range(epochs):
    print(f"Epoch {epoch}")
    d_loss_epoch_sum = 0
    d_loss_epoch_avg = 0
    d_loss_real_epoch_sum = 0
    d_loss_fake_epoch_sum = 0
    d_loss_real_epoch_avg = 0
    d_loss_fake_epoch_avg = 0
    
    g_loss_epoch_sum = 0
    g_loss_epoch_avg = 0
    
    data_iter = iter(data_loader) #redo for each epoch otherwise it goes through the same batch
    for it in range(60000//mb_size): # Sample data
        
        #D_solver.zero_grad()#reset gradient accumulation (not in article) but is more modern i think
        
        #z = torch.randn(mb_size, Z_dim) #random z vector of dimension batch size * z_dim (64*100)
        z = torch.randn(mb_size, Z_dim).to(device) #random z vector of dimension batch size * z_dim (64*100) GPU accelerated
        
        X, y = next(data_iter) #get next sample from mnist
        
        #X = X.view(mb_size, -1) #flatten from [64, 1, 28, 28](mnist) to [batch size,784]
        X = X.view(mb_size, -1).to(device) #flatten from [64, 1, 28, 28](mnist) to [batch size,784] GPU accelerated
    
        #!!!!Task 3
        #one hot encoding for c. We get y as a label (eg. "2") we need to convert this into a vector of [0,0,1,0...]
        c = torch.zeros(mb_size, y_dim).to(device)  # (batch_size, 10) all zeros
        c[torch.arange(mb_size), y] = 1             # set the correct class column to 1
        #!!!!Task 3
        
        #Discriminator forward-loss-backward-update
        #!!!!Task 3
        G_sample = G(z,c)
        D_real = D(X,c)
        D_fake = D(G_sample,c)
        #!!!!Task 3
        ones_label = torch.ones_like(D_real).to(device) #batch size big vector of 1 or smaller if D(X) gives out smaller batch
        zeros_label = torch.zeros_like(D_fake).to(device)#batch size big vector of 0 or smaller if D(X) gives out smaller batch
        #!!!!Task2
        D_loss_real = nn.binary_cross_entropy_with_logits(D_real, ones_label)
        D_loss_fake = nn.binary_cross_entropy_with_logits(D_fake, zeros_label)
        #!!!!Task2
        D_loss = D_loss_real + D_loss_fake
        d_loss_epoch_sum += D_loss.item()
        d_loss_real_epoch_sum += D_loss_real.item()
        d_loss_fake_epoch_sum += D_loss_fake.item()
        
        
        D_loss.backward()
        D_solver.step()
        reset_grad()
        # Generator forward-loss-backward-update
        z = torch.randn(mb_size, Z_dim).to(device) #random z vector of dimension batch size * z_dim (64*100) GPU accelerated
        G_sample = G(z,c)
        D_fake = D(G_sample,c)
        #!!!!Task2
        G_loss = nn.binary_cross_entropy_with_logits(D_fake, ones_label)
        #!!!!Task2
        g_loss_epoch_sum += G_loss.item() 
        G_loss.backward()
        G_solver.step()
        
        # Housekeeping - reset gradient
        reset_grad()
        
        if it % 100 == 0:
            print(f"Iter {it} | D_loss: {D_loss.item():.4f} | G_loss: {G_loss.item():.4f}")

    #log avg loss per epoch
    g_loss_epoch_avg = g_loss_epoch_sum / (60000//mb_size)
    d_loss_epoch_avg = d_loss_epoch_sum / (60000//mb_size)
    d_loss_real_epoch_avg = d_loss_real_epoch_sum / (60000//mb_size)
    d_loss_fake_epoch_avg = d_loss_fake_epoch_sum / (60000//mb_size)
    
    experiment.log_metrics({
        "D_loss_epoch": d_loss_epoch_avg,
        "G_loss_epoch": g_loss_epoch_avg,
        "D_loss_real": d_loss_real_epoch_avg,
        "D_loss_fake": d_loss_fake_epoch_avg
    }, step=epoch)
            
    #save image each epoch
    with torch.no_grad():
        z = torch.randn(mb_size, Z_dim).to(device)
        samples = G(z,c).detach().cpu()
    
        samples = samples.view(mb_size, 1, 28, 28)
    
        # make a proper 8x8 grid (64 images)
        grid = torch.zeros(28 * 8, 28 * 8)
    
        k = 0
        for i in range(8):
            for j in range(8):
                grid[i*28:(i+1)*28, j*28:(j+1)*28] = samples[k, 0]
                k += 1
    
        plt.imshow(grid, cmap='gray')
        plt.axis('off')
        plt.savefig(f"./task3_images/task3_epoch_{epoch}.png")
        plt.close()
# Save model after last epoch
torch.save({
    'G_params': {
        'Wzh': Wzh.data,
        'bzh': bzh.data,
        'Whx': Whx.data,
        'bhx': bhx.data
    },
    'D_params': {
        'Wxh': Wxh.data,
        'bxh': bxh.data,
        'Why': Why.data,
        'bhy': bhy.data
    }
}, f"./models/task3_model_{run_name}.pth")
experiment.end()
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/drmrai/d7047e-lab2/0609616dbcfc4a10b9c43c00ab9cdb2e
#
# COMET INFO: Couldn't find a Git repository in '/home/jovyan/lab2' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Epoch 0
# Iter 0 | D_loss: 1.8663 | G_loss: 2.2583
# Iter 100 | D_loss: 0.1689 | G_loss: 5.3355
# Iter 200 | D_loss: 0.0837 | G_loss: 6.6325
# Iter 300 | D_loss: 0.0036 | G_loss: 7.0046
# Iter 400 | D_loss: 0.0081 | G_loss: 7.2234
# Iter 500 | D_loss: 0.0117 | G_loss: 7.1055
# Iter 600 | D_loss: 0.0015 | G_loss: 7.6652
# Iter 700 | D_loss: 0.0012 | G_loss: 8.4437
# Iter 800 | D_loss: 0.0016 | G_loss: 10.2354
# Iter 900 | D_loss: 0.0016 | G_loss: 8.9439
# Epoch 1
# Iter 0 | D_loss: 0.0012 | G_loss: 8.3920
# Iter 100 | D_loss: 0.0041 | G_loss: 8.5723
# Iter 200 | D_loss: 0.0027 | G_loss: 7.4457
# Iter 300 | D_loss: 0.0004 | G_loss: 10.7004
# Iter 400 | D_loss: 0.0016 | G_loss: 10.1317
# Iter 500 | D_loss: 0.0025 | G_loss: 9.9056
# Iter 600 | D_loss: 0.0004 | G_loss: 10.5944
# Iter 700 | D_loss: 0.0017 | G_loss: 9.3706
# Iter 800 | D_loss: 0.0010 | G_loss: 10.2594
# Iter 900 | D_loss: 0.0008 | G_loss: 10.8227
# Epoch 2
# Iter 0 | D_loss: 0.0013 | G_loss: 8.1221
# Iter 100 | D_loss: 0.0032 | G_loss: 8.3130
# Iter 200 | D_loss: 0.0015 | G_loss: 8.1349
# Iter 300 | D_loss: 0.0017 | G_loss: 8.5371
# Iter 400 | D_loss: 0.0009 | G_loss: 8.3170
# Iter 500 | D_loss: 0.0025 | G_loss: 7.8577
# Iter 600 | D_loss: 0.0007 | G_loss: 9.3646
# Iter 700 | D_loss: 0.0005 | G_loss: 12.1680
# Iter 800 | D_loss: 0.0003 | G_loss: 10.0316
# Iter 900 | D_loss: 0.0007 | G_loss: 9.1414
# Epoch 3
# Iter 0 | D_loss: 0.0023 | G_loss: 9.3393
# Iter 100 | D_loss: 0.0006 | G_loss: 9.8451
# Iter 200 | D_loss: 0.0005 | G_loss: 10.6355
# Iter 300 | D_loss: 0.0005 | G_loss: 11.5627
# Iter 400 | D_loss: 0.0018 | G_loss: 9.1318
# Iter 500 | D_loss: 0.0049 | G_loss: 8.8848
# Iter 600 | D_loss: 0.0065 | G_loss: 8.5150
# Iter 700 | D_loss: 0.0009 | G_loss: 9.4288
# Iter 800 | D_loss: 0.0014 | G_loss: 8.2589
# Iter 900 | D_loss: 0.0028 | G_loss: 7.3045
# Epoch 4
# Iter 0 | D_loss: 0.0010 | G_loss: 9.6077
# Iter 100 | D_loss: 0.0008 | G_loss: 9.3479
# Iter 200 | D_loss: 0.0007 | G_loss: 10.2925
# Iter 300 | D_loss: 0.0006 | G_loss: 9.7544
# Iter 400 | D_loss: 0.0003 | G_loss: 9.9781
# Iter 500 | D_loss: 0.0013 | G_loss: 12.0463
# Iter 600 | D_loss: 0.0005 | G_loss: 13.3277
# Iter 700 | D_loss: 0.0001 | G_loss: 10.6478
# Iter 800 | D_loss: 0.0024 | G_loss: 12.3780
# Iter 900 | D_loss: 0.0004 | G_loss: 10.0774
# Epoch 5
# Iter 0 | D_loss: 0.0004 | G_loss: 10.9321
# Iter 100 | D_loss: 0.0007 | G_loss: 14.8307
# Iter 200 | D_loss: 0.0001 | G_loss: 15.6301
# Iter 300 | D_loss: 0.0002 | G_loss: 21.0269
# Iter 400 | D_loss: 0.0013 | G_loss: 10.7621
# Iter 500 | D_loss: 0.0007 | G_loss: 15.1605
# Iter 600 | D_loss: 0.0004 | G_loss: 12.1930
# Iter 700 | D_loss: 0.0004 | G_loss: 10.1561
# Iter 800 | D_loss: 0.0021 | G_loss: 11.9097
# Iter 900 | D_loss: 0.0072 | G_loss: 9.4358
# Epoch 6
# Iter 0 | D_loss: 0.0066 | G_loss: 10.4173
# Iter 100 | D_loss: 0.0008 | G_loss: 9.9397
# Iter 200 | D_loss: 0.0001 | G_loss: 12.0479
# Iter 300 | D_loss: 0.0008 | G_loss: 12.7804
# Iter 400 | D_loss: 0.0014 | G_loss: 12.2411
# Iter 500 | D_loss: 0.0002 | G_loss: 13.3365
# Iter 600 | D_loss: 0.0003 | G_loss: 12.5659
# Iter 700 | D_loss: 0.0020 | G_loss: 12.6134
# Iter 800 | D_loss: 0.0009 | G_loss: 10.3854
# Iter 900 | D_loss: 0.0001 | G_loss: 10.7401
# Epoch 7
# Iter 0 | D_loss: 0.0001 | G_loss: 13.6160
# Iter 100 | D_loss: 0.0010 | G_loss: 12.0070
# Iter 200 | D_loss: 0.0014 | G_loss: 13.6955
# Iter 300 | D_loss: 0.0000 | G_loss: 16.5769
# Iter 400 | D_loss: 0.0000 | G_loss: 17.6396
# Iter 500 | D_loss: 0.0001 | G_loss: 11.5263
# Iter 600 | D_loss: 0.0008 | G_loss: 12.8329
# Iter 700 | D_loss: 0.0002 | G_loss: 21.0664
# Iter 800 | D_loss: 0.0016 | G_loss: 18.5129
# Iter 900 | D_loss: 0.0005 | G_loss: 12.1889
# Epoch 8
# Iter 0 | D_loss: 0.0588 | G_loss: 21.6141
# Iter 100 | D_loss: 0.0004 | G_loss: 13.4453
# Iter 200 | D_loss: 0.0017 | G_loss: 12.8869
# Iter 300 | D_loss: 0.0024 | G_loss: 13.4132
# Iter 400 | D_loss: 0.0001 | G_loss: 11.5659
# Iter 500 | D_loss: 0.0004 | G_loss: 11.8988
# Iter 600 | D_loss: 0.0003 | G_loss: 11.2037
# Iter 700 | D_loss: 0.0113 | G_loss: 14.8208
# Iter 800 | D_loss: 0.0005 | G_loss: 10.1231
# Iter 900 | D_loss: 0.0020 | G_loss: 12.2998
# Epoch 9
# Iter 0 | D_loss: 0.0002 | G_loss: 11.8098
# Iter 100 | D_loss: 0.0001 | G_loss: 14.5629
# Iter 200 | D_loss: 0.0000 | G_loss: 13.8069
# Iter 300 | D_loss: 0.0000 | G_loss: 15.5763
# Iter 400 | D_loss: 0.0009 | G_loss: 15.3673
# Iter 500 | D_loss: 0.0002 | G_loss: 12.8873
# Iter 600 | D_loss: 0.0040 | G_loss: 24.4672
# Iter 700 | D_loss: 0.0000 | G_loss: 13.8036
# Iter 800 | D_loss: 0.0001 | G_loss: 13.7684
# Iter 900 | D_loss: 0.0000 | G_loss: 14.7094
# Epoch 10
# Iter 0 | D_loss: 0.0000 | G_loss: 13.6546
# Iter 100 | D_loss: 0.0000 | G_loss: 13.5022
# Iter 200 | D_loss: 0.0000 | G_loss: 14.3159
# Iter 300 | D_loss: 0.0000 | G_loss: 13.0668
# Iter 400 | D_loss: 0.0000 | G_loss: 14.2464
# Iter 500 | D_loss: 0.0000 | G_loss: 14.1007
# Iter 600 | D_loss: 0.0000 | G_loss: 14.6726
# Iter 700 | D_loss: 0.0000 | G_loss: 15.5075
# Iter 800 | D_loss: 0.0000 | G_loss: 15.7402
# Iter 900 | D_loss: 0.0000 | G_loss: 15.4207
# Epoch 11
# Iter 0 | D_loss: 0.0000 | G_loss: 14.9534
# Iter 100 | D_loss: 0.0000 | G_loss: 15.1253
# Iter 200 | D_loss: 0.0000 | G_loss: 14.3580
# Iter 300 | D_loss: 0.0000 | G_loss: 14.8898
# Iter 400 | D_loss: 0.0000 | G_loss: 13.9716
# Iter 500 | D_loss: 0.0000 | G_loss: 14.9940
# Iter 600 | D_loss: 0.0000 | G_loss: 14.3729
# Iter 700 | D_loss: 0.0000 | G_loss: 14.3687
# Iter 800 | D_loss: 0.0000 | G_loss: 15.6107
# Iter 900 | D_loss: 0.0000 | G_loss: 15.7180
# Epoch 12
# Iter 0 | D_loss: 0.0000 | G_loss: 15.5011
# Iter 100 | D_loss: 0.0000 | G_loss: 15.5466
# Iter 200 | D_loss: 0.0000 | G_loss: 14.8935
# Iter 300 | D_loss: 0.0000 | G_loss: 15.8965
# Iter 400 | D_loss: 0.0000 | G_loss: 16.2003
# Iter 500 | D_loss: 0.0000 | G_loss: 15.9504
# Iter 600 | D_loss: 0.0000 | G_loss: 16.6789
# Iter 700 | D_loss: 0.0000 | G_loss: 17.0796
# Iter 800 | D_loss: 0.0000 | G_loss: 17.3632
# Iter 900 | D_loss: 0.0000 | G_loss: 17.0834
# Epoch 13
# Iter 0 | D_loss: 0.0000 | G_loss: 16.8439
# Iter 100 | D_loss: 0.0000 | G_loss: 15.6806
# Iter 200 | D_loss: 0.0000 | G_loss: 15.7112
# Iter 300 | D_loss: 0.0000 | G_loss: 16.3736
# Iter 400 | D_loss: 0.0000 | G_loss: 16.7133
# Iter 500 | D_loss: 0.0000 | G_loss: 16.3964
# Iter 600 | D_loss: 0.0000 | G_loss: 17.4220
# Iter 700 | D_loss: 0.0000 | G_loss: 15.5572
# Iter 800 | D_loss: 0.0000 | G_loss: 17.2892
# Iter 900 | D_loss: 0.0000 | G_loss: 17.2380
# Epoch 14
# Iter 0 | D_loss: 0.0000 | G_loss: 16.8230
# Iter 100 | D_loss: 0.0000 | G_loss: 16.3413
# Iter 200 | D_loss: 0.0000 | G_loss: 16.9649
# Iter 300 | D_loss: 0.0000 | G_loss: 17.0507
# Iter 400 | D_loss: 0.0000 | G_loss: 15.1610
# Iter 500 | D_loss: 0.0000 | G_loss: 15.4902
# Iter 600 | D_loss: 0.0000 | G_loss: 16.6924
# Iter 700 | D_loss: 0.0000 | G_loss: 14.6808
# Iter 800 | D_loss: 0.0000 | G_loss: 33.1913
# Iter 900 | D_loss: 0.0002 | G_loss: 14.6702
# Epoch 15
# Iter 0 | D_loss: 0.0022 | G_loss: 17.4116
# Iter 100 | D_loss: 0.0001 | G_loss: 11.5579
# Iter 200 | D_loss: 0.0000 | G_loss: 14.1526
# Iter 300 | D_loss: 0.0001 | G_loss: 14.7766
# Iter 400 | D_loss: 0.0000 | G_loss: 15.1423
# Iter 500 | D_loss: 0.0000 | G_loss: 11.5066
# Iter 600 | D_loss: 0.0026 | G_loss: 12.5446
# Iter 700 | D_loss: 0.0003 | G_loss: 39.9044
# Iter 800 | D_loss: 0.0000 | G_loss: 14.4464
# Iter 900 | D_loss: 0.0000 | G_loss: 15.5224
# Epoch 16
# Iter 0 | D_loss: 0.0000 | G_loss: 16.5643
# Iter 100 | D_loss: 0.0000 | G_loss: 13.8567
# Iter 200 | D_loss: 0.0000 | G_loss: 17.7462
# Iter 300 | D_loss: 0.0000 | G_loss: 13.8574
# Iter 400 | D_loss: 0.0000 | G_loss: 16.2109
# Iter 500 | D_loss: 0.0008 | G_loss: 18.0661
# Iter 600 | D_loss: 0.0000 | G_loss: 20.0113
# Iter 700 | D_loss: 0.0001 | G_loss: 13.0860
# Iter 800 | D_loss: 0.0002 | G_loss: 11.2707
# Iter 900 | D_loss: 0.0000 | G_loss: 14.9904
# Epoch 17
# Iter 0 | D_loss: 0.0000 | G_loss: 15.8559
# Iter 100 | D_loss: 0.0837 | G_loss: 10.9772
# Iter 200 | D_loss: 0.0000 | G_loss: 18.6902
# Iter 300 | D_loss: 0.0007 | G_loss: 11.4526
# Iter 400 | D_loss: 0.0000 | G_loss: 14.9463
# Iter 500 | D_loss: 0.0000 | G_loss: 13.1458
# Iter 600 | D_loss: 0.0008 | G_loss: 15.3359
# Iter 700 | D_loss: 0.0000 | G_loss: 25.8357
# Iter 800 | D_loss: 0.0000 | G_loss: 13.9866
# Iter 900 | D_loss: 0.0000 | G_loss: 16.9697
# Epoch 18
# Iter 0 | D_loss: 0.0000 | G_loss: 16.6843
# Iter 100 | D_loss: 0.0000 | G_loss: 22.2072
# Iter 200 | D_loss: 0.0009 | G_loss: 19.6849
# Iter 300 | D_loss: 0.0000 | G_loss: 34.5297
# Iter 400 | D_loss: 0.0008 | G_loss: 17.3805
# Iter 500 | D_loss: 0.0001 | G_loss: 21.5873
# Iter 600 | D_loss: 0.0009 | G_loss: 19.6478
# Iter 700 | D_loss: 0.0000 | G_loss: 30.1377
# Iter 800 | D_loss: 0.0012 | G_loss: 16.1717
# Iter 900 | D_loss: 0.0000 | G_loss: 35.3405
# Epoch 19
# Iter 0 | D_loss: 0.0000 | G_loss: 18.8168
# Iter 100 | D_loss: 0.0000 | G_loss: 18.7500
# Iter 200 | D_loss: 0.0000 | G_loss: 19.6550
# Iter 300 | D_loss: 0.0001 | G_loss: 26.3041
# Iter 400 | D_loss: 0.0000 | G_loss: 23.1391
# Iter 500 | D_loss: 0.0003 | G_loss: 16.5871
# Iter 600 | D_loss: 0.0005 | G_loss: 16.5189
# Iter 700 | D_loss: 0.0000 | G_loss: 16.1148
# Iter 800 | D_loss: 0.0001 | G_loss: 15.7232
# Iter 900 | D_loss: 0.0001 | G_loss: 13.9963
# Epoch 20
# Iter 0 | D_loss: 0.0002 | G_loss: 13.8718
# Iter 100 | D_loss: 0.0000 | G_loss: 14.7887
# Iter 200 | D_loss: 0.0003 | G_loss: 12.7899
# Iter 300 | D_loss: 0.0000 | G_loss: 27.1643
# Iter 400 | D_loss: 0.0070 | G_loss: 10.0710
# Iter 500 | D_loss: 0.0079 | G_loss: 13.7348
# Iter 600 | D_loss: 0.0002 | G_loss: 13.0134
# Iter 700 | D_loss: 0.0036 | G_loss: 12.6973
# Iter 800 | D_loss: 0.0000 | G_loss: 16.6913
# Iter 900 | D_loss: 0.0013 | G_loss: 12.8414
# Epoch 21
# Iter 0 | D_loss: 0.0003 | G_loss: 15.8173
# Iter 100 | D_loss: 0.0041 | G_loss: 12.4503
# Iter 200 | D_loss: 0.0000 | G_loss: 14.9675
# Iter 300 | D_loss: 0.0002 | G_loss: 16.4775
# Iter 400 | D_loss: 0.0000 | G_loss: 16.0051
# Iter 500 | D_loss: 0.0001 | G_loss: 14.2987
# Iter 600 | D_loss: 0.0001 | G_loss: 16.7695
# Iter 700 | D_loss: 0.0000 | G_loss: 13.5961
# Iter 800 | D_loss: 0.0000 | G_loss: 17.4314
# Iter 900 | D_loss: 0.0001 | G_loss: 12.9326
# Epoch 22
# Iter 0 | D_loss: 0.0000 | G_loss: 16.1972
# Iter 100 | D_loss: 0.0009 | G_loss: 13.4922
# Iter 200 | D_loss: 0.0056 | G_loss: 13.3147
# Iter 300 | D_loss: 0.0007 | G_loss: 12.0951
# Iter 400 | D_loss: 0.0002 | G_loss: 23.9577
# Iter 500 | D_loss: 0.0419 | G_loss: 29.0348
# Iter 600 | D_loss: 0.0001 | G_loss: 22.2274
# Iter 700 | D_loss: 0.0000 | G_loss: 22.2560
# Iter 800 | D_loss: 0.0001 | G_loss: 14.5139
# Iter 900 | D_loss: 0.0000 | G_loss: 17.3246
# Epoch 23
# Iter 0 | D_loss: 0.0000 | G_loss: 21.8391
# Iter 100 | D_loss: 0.0000 | G_loss: 26.9582
# Iter 200 | D_loss: 0.0001 | G_loss: 17.0714
# Iter 300 | D_loss: 0.0000 | G_loss: 17.0635
# Iter 400 | D_loss: 0.0000 | G_loss: 20.5709
# Iter 500 | D_loss: 0.0000 | G_loss: 14.9202
# Iter 600 | D_loss: 0.0000 | G_loss: 14.2134
# Iter 700 | D_loss: 0.0000 | G_loss: 13.8385
# Iter 800 | D_loss: 0.0000 | G_loss: 18.4901
# Iter 900 | D_loss: 0.0000 | G_loss: 13.7006
# Epoch 24
# Iter 0 | D_loss: 0.0000 | G_loss: 16.8414
# Iter 100 | D_loss: 0.0000 | G_loss: 15.3997
# Iter 200 | D_loss: 0.0000 | G_loss: 16.3816
# Iter 300 | D_loss: 0.0000 | G_loss: 16.0267
# Iter 400 | D_loss: 0.0000 | G_loss: 16.3793
# Iter 500 | D_loss: 0.0001 | G_loss: 18.5002
# Iter 600 | D_loss: 0.0000 | G_loss: 15.2059
# Iter 700 | D_loss: 0.0000 | G_loss: 15.2897
# Iter 800 | D_loss: 0.0000 | G_loss: 15.4607
# Iter 900 | D_loss: 0.0000 | G_loss: 16.0231
# Epoch 25
# Iter 0 | D_loss: 0.0000 | G_loss: 15.9445
# Iter 100 | D_loss: 0.0000 | G_loss: 15.2384
# Iter 200 | D_loss: 0.0000 | G_loss: 15.6936
# Iter 300 | D_loss: 0.0000 | G_loss: 17.5745
# Iter 400 | D_loss: 0.0000 | G_loss: 17.9004
# Iter 500 | D_loss: 0.0000 | G_loss: 18.5819
# Iter 600 | D_loss: 0.0000 | G_loss: 18.0781
# Iter 700 | D_loss: 0.0000 | G_loss: 18.0584
# Iter 800 | D_loss: 0.0000 | G_loss: 18.0860
# Iter 900 | D_loss: 0.0000 | G_loss: 18.5782
# Epoch 26
# Iter 0 | D_loss: 0.0000 | G_loss: 17.6536
# Iter 100 | D_loss: 0.0000 | G_loss: 17.6833
# Iter 200 | D_loss: 0.0000 | G_loss: 17.1049
# Iter 300 | D_loss: 0.0000 | G_loss: 18.0368
# Iter 400 | D_loss: 0.0000 | G_loss: 18.1041
# Iter 500 | D_loss: 0.0000 | G_loss: 19.1113
# Iter 600 | D_loss: 0.0000 | G_loss: 20.0031
# Iter 700 | D_loss: 0.0000 | G_loss: 19.7636
# Iter 800 | D_loss: 0.0000 | G_loss: 18.8519
# Iter 900 | D_loss: 0.0000 | G_loss: 17.7414
# Epoch 27
# Iter 0 | D_loss: 0.0000 | G_loss: 18.5555
# Iter 100 | D_loss: 0.0000 | G_loss: 18.2153
# Iter 200 | D_loss: 0.0000 | G_loss: 18.5040
# Iter 300 | D_loss: 0.0000 | G_loss: 17.9355
# Iter 400 | D_loss: 0.0000 | G_loss: 18.5504
# Iter 500 | D_loss: 0.0000 | G_loss: 19.5636
# Iter 600 | D_loss: 0.0000 | G_loss: 18.2385
# Iter 700 | D_loss: 0.0000 | G_loss: 19.3716
# Iter 800 | D_loss: 0.0000 | G_loss: 18.1904
# Iter 900 | D_loss: 0.0000 | G_loss: 19.3227
# Epoch 28
# Iter 0 | D_loss: 0.0000 | G_loss: 19.5166
# Iter 100 | D_loss: 0.0000 | G_loss: 18.5776
# Iter 200 | D_loss: 0.0000 | G_loss: 19.9625
# Iter 300 | D_loss: 0.0000 | G_loss: 19.5539
# Iter 400 | D_loss: 0.0000 | G_loss: 19.9255
# Iter 500 | D_loss: 0.0000 | G_loss: 19.3396
# Iter 600 | D_loss: 0.0000 | G_loss: 19.6434
# Iter 700 | D_loss: 0.0000 | G_loss: 19.2832
# Iter 800 | D_loss: 0.0000 | G_loss: 19.5884
# Iter 900 | D_loss: 0.0000 | G_loss: 20.3066
# Epoch 29
# Iter 0 | D_loss: 0.0000 | G_loss: 19.8863
# Iter 100 | D_loss: 0.0000 | G_loss: 19.1021
# Iter 200 | D_loss: 0.0000 | G_loss: 20.0304
# Iter 300 | D_loss: 0.0000 | G_loss: 24.2694
# Iter 400 | D_loss: 0.0000 | G_loss: 21.6769
# Iter 500 | D_loss: 0.0000 | G_loss: 18.7814
# Iter 600 | D_loss: 0.0000 | G_loss: 18.6833
# Iter 700 | D_loss: 0.0000 | G_loss: 18.9329
# Iter 800 | D_loss: 0.0000 | G_loss: 19.1404
# Iter 900 | D_loss: 0.0000 | G_loss: 22.9932
# Epoch 30
# Iter 0 | D_loss: 0.0000 | G_loss: 22.6687
# Iter 100 | D_loss: 0.0000 | G_loss: 19.0124
# Iter 200 | D_loss: 0.0000 | G_loss: 18.2116
# Iter 300 | D_loss: 0.0000 | G_loss: 18.0208
# Iter 400 | D_loss: 0.0000 | G_loss: 23.1502
# Iter 500 | D_loss: 0.0000 | G_loss: 19.4707
# Iter 600 | D_loss: 0.0000 | G_loss: 20.9254
# Iter 700 | D_loss: 0.0000 | G_loss: 25.3817
# Iter 800 | D_loss: 0.0000 | G_loss: 18.2568
# Iter 900 | D_loss: 0.0000 | G_loss: 36.5191
# Epoch 31
# Iter 0 | D_loss: 0.0000 | G_loss: 27.3923
# Iter 100 | D_loss: 0.0000 | G_loss: 16.4230
# Iter 200 | D_loss: 0.0000 | G_loss: 75.8444
# Iter 300 | D_loss: 0.0000 | G_loss: 27.1552
# Iter 400 | D_loss: 0.0000 | G_loss: 17.3011
# Iter 500 | D_loss: 0.0000 | G_loss: 13.9309
# Iter 600 | D_loss: 0.0000 | G_loss: 13.8712
# Iter 700 | D_loss: 0.0000 | G_loss: 27.2768
# Iter 800 | D_loss: 0.0000 | G_loss: 16.9367
# Iter 900 | D_loss: 0.0000 | G_loss: 20.0262
# Epoch 32
# Iter 0 | D_loss: 0.0000 | G_loss: 20.6381
# Iter 100 | D_loss: 0.0000 | G_loss: 29.0591
# Iter 200 | D_loss: 0.0000 | G_loss: 25.4692
# Iter 300 | D_loss: 0.0000 | G_loss: 36.9605
# Iter 400 | D_loss: 0.0000 | G_loss: 16.1316
# Iter 500 | D_loss: 0.0000 | G_loss: 17.7118
# Iter 600 | D_loss: 0.0000 | G_loss: 28.2588
# Iter 700 | D_loss: 0.0000 | G_loss: 16.8621
# Iter 800 | D_loss: 0.0000 | G_loss: 23.4309
# Iter 900 | D_loss: 0.0000 | G_loss: 19.6816
# Epoch 33
# Iter 0 | D_loss: 0.0000 | G_loss: 21.8017
# Iter 100 | D_loss: 0.0000 | G_loss: 21.0141
# Iter 200 | D_loss: 0.0000 | G_loss: 17.2077
# Iter 300 | D_loss: 0.0000 | G_loss: 30.3040
# Iter 400 | D_loss: 0.0000 | G_loss: 14.7886
# Iter 500 | D_loss: 0.0007 | G_loss: 17.7806
# Iter 600 | D_loss: 0.0061 | G_loss: 77.6153
# Iter 700 | D_loss: 0.0000 | G_loss: 48.0882
# Iter 800 | D_loss: 0.0000 | G_loss: 19.6374
# Iter 900 | D_loss: 0.0000 | G_loss: 19.1522
# Epoch 34
# Iter 0 | D_loss: 0.0000 | G_loss: 18.1189
# Iter 100 | D_loss: 0.0000 | G_loss: 16.3038
# Iter 200 | D_loss: 0.0001 | G_loss: 19.7755
# Iter 300 | D_loss: 0.0000 | G_loss: 29.0242
# Iter 400 | D_loss: 0.0000 | G_loss: 37.7630
# Iter 500 | D_loss: 0.0000 | G_loss: 18.5173
# Iter 600 | D_loss: 0.0000 | G_loss: 14.7884
# Iter 700 | D_loss: 0.0000 | G_loss: 25.5765
# Iter 800 | D_loss: 0.0000 | G_loss: 23.8745
# Iter 900 | D_loss: 0.0001 | G_loss: 16.2606
# Epoch 35
# Iter 0 | D_loss: 0.0000 | G_loss: 19.8807
# Iter 100 | D_loss: 0.0000 | G_loss: 23.1389
# Iter 200 | D_loss: 0.0001 | G_loss: 49.6100
# Iter 300 | D_loss: 0.0000 | G_loss: 23.9698
# Iter 400 | D_loss: 0.0000 | G_loss: 20.2787
# Iter 500 | D_loss: 0.0000 | G_loss: 14.8481
# Iter 600 | D_loss: 0.0000 | G_loss: 13.4797
# Iter 700 | D_loss: 0.0000 | G_loss: 13.6115
# Iter 800 | D_loss: 0.0845 | G_loss: 16.7734
# Iter 900 | D_loss: 0.0000 | G_loss: 15.7011
# Epoch 36
# Iter 0 | D_loss: 0.0000 | G_loss: 15.5034
# Iter 100 | D_loss: 0.0000 | G_loss: 15.4905
# Iter 200 | D_loss: 0.0000 | G_loss: 17.1176
# Iter 300 | D_loss: 0.0005 | G_loss: 14.6192
# Iter 400 | D_loss: 0.0000 | G_loss: 15.2082
# Iter 500 | D_loss: 0.0000 | G_loss: 15.7223
# Iter 600 | D_loss: 0.0017 | G_loss: 28.1104
# Iter 700 | D_loss: 0.0000 | G_loss: 33.2212
# Iter 800 | D_loss: 0.0000 | G_loss: 16.8446
# Iter 900 | D_loss: 0.0000 | G_loss: 16.9981
# Epoch 37
# Iter 0 | D_loss: 0.0000 | G_loss: 25.9059
# Iter 100 | D_loss: 0.0054 | G_loss: 29.0325
# Iter 200 | D_loss: 0.0000 | G_loss: 15.7963
# Iter 300 | D_loss: 0.0000 | G_loss: 31.1945
# Iter 400 | D_loss: 0.0000 | G_loss: 32.1678
# Iter 500 | D_loss: 0.0000 | G_loss: 21.7162
# Iter 600 | D_loss: 0.0000 | G_loss: 29.9543
# Iter 700 | D_loss: 0.0000 | G_loss: 47.5297
# Iter 800 | D_loss: 0.0000 | G_loss: 15.7519
# Iter 900 | D_loss: 0.0036 | G_loss: 14.4838
# Epoch 38
# Iter 0 | D_loss: 0.0001 | G_loss: 20.3183
# Iter 100 | D_loss: 0.0000 | G_loss: 18.8300
# Iter 200 | D_loss: 0.0000 | G_loss: 18.5316
# Iter 300 | D_loss: 0.0000 | G_loss: 19.0825
# Iter 400 | D_loss: 0.0081 | G_loss: 25.3589
# Iter 500 | D_loss: 0.0000 | G_loss: 16.1582
# Iter 600 | D_loss: 0.0000 | G_loss: 26.0564
# Iter 700 | D_loss: 0.0000 | G_loss: 18.7328
# Iter 800 | D_loss: 0.0000 | G_loss: 16.4514
# Iter 900 | D_loss: 0.0000 | G_loss: 16.9627
# Epoch 39
# Iter 0 | D_loss: 0.0018 | G_loss: 22.0176
# Iter 100 | D_loss: 0.0001 | G_loss: 15.8935
# Iter 200 | D_loss: 0.0000 | G_loss: 18.6449
# Iter 300 | D_loss: 0.0000 | G_loss: 25.4519
# Iter 400 | D_loss: 0.0014 | G_loss: 14.7820
# Iter 500 | D_loss: 0.0000 | G_loss: 18.5546
# Iter 600 | D_loss: 0.0000 | G_loss: 55.7675
# Iter 700 | D_loss: 0.0003 | G_loss: 18.4166
# Iter 800 | D_loss: 0.0000 | G_loss: 24.2441
# Iter 900 | D_loss: 0.0000 | G_loss: 34.8388
# Epoch 40
# Iter 0 | D_loss: 0.0000 | G_loss: 22.1926
# Iter 100 | D_loss: 0.0000 | G_loss: 43.8120
# Iter 200 | D_loss: 0.0000 | G_loss: 20.1851
# Iter 300 | D_loss: 0.0002 | G_loss: 20.6225
# Iter 400 | D_loss: 0.0004 | G_loss: 19.4423
# Iter 500 | D_loss: 0.0000 | G_loss: 25.0704
# Iter 600 | D_loss: 0.0002 | G_loss: 19.2116
# Iter 700 | D_loss: 0.0000 | G_loss: 14.0149
# Iter 800 | D_loss: 0.0000 | G_loss: 16.0572
# Iter 900 | D_loss: 0.0000 | G_loss: 19.0928
# Epoch 41
# Iter 0 | D_loss: 0.0000 | G_loss: 16.7065
# Iter 100 | D_loss: 0.0000 | G_loss: 16.6142
# Iter 200 | D_loss: 0.0000 | G_loss: 23.2962
# Iter 300 | D_loss: 0.0000 | G_loss: 15.2281
# Iter 400 | D_loss: 0.0000 | G_loss: 14.3838
# Iter 500 | D_loss: 0.0000 | G_loss: 15.2246
# Iter 600 | D_loss: 0.0000 | G_loss: 14.9829
# Iter 700 | D_loss: 0.0000 | G_loss: 14.1212
# Iter 800 | D_loss: 0.0000 | G_loss: 21.7116
# Iter 900 | D_loss: 0.0000 | G_loss: 17.7068
# Epoch 42
# Iter 0 | D_loss: 0.0000 | G_loss: 16.8879
# Iter 100 | D_loss: 0.0000 | G_loss: 29.6424
# Iter 200 | D_loss: 0.0000 | G_loss: 22.8172
# Iter 300 | D_loss: 0.0000 | G_loss: 56.6549
# Iter 400 | D_loss: 0.0000 | G_loss: 19.6414
# Iter 500 | D_loss: 0.0000 | G_loss: 19.1480
# Iter 600 | D_loss: 0.0000 | G_loss: 17.8026
# Iter 700 | D_loss: 0.0000 | G_loss: 18.7910
# Iter 800 | D_loss: 0.0000 | G_loss: 21.7575
# Iter 900 | D_loss: 0.0000 | G_loss: 17.1480
# Epoch 43
# Iter 0 | D_loss: 0.0000 | G_loss: 15.2207
# Iter 100 | D_loss: 0.0000 | G_loss: 15.4619
# Iter 200 | D_loss: 0.0001 | G_loss: 20.0203
# Iter 300 | D_loss: 0.0000 | G_loss: 27.7915
# Iter 400 | D_loss: 0.0001 | G_loss: 16.4727
# Iter 500 | D_loss: 0.0000 | G_loss: 57.3679
# Iter 600 | D_loss: 0.0000 | G_loss: 15.1345
# Iter 700 | D_loss: 0.0000 | G_loss: 18.9491
# Iter 800 | D_loss: 0.0000 | G_loss: 19.7437
# Iter 900 | D_loss: 0.0000 | G_loss: 18.1310
# Epoch 44
# Iter 0 | D_loss: 0.0000 | G_loss: 18.3213
# Iter 100 | D_loss: 0.0000 | G_loss: 19.9442
# Iter 200 | D_loss: 0.0000 | G_loss: 55.2492
# Iter 300 | D_loss: 0.0000 | G_loss: 32.8865
# Iter 400 | D_loss: 0.0000 | G_loss: 23.2008
# Iter 500 | D_loss: 0.0317 | G_loss: 18.0103
# Iter 600 | D_loss: 0.0000 | G_loss: 59.8686
# Iter 700 | D_loss: 0.0000 | G_loss: 49.8535
# Iter 800 | D_loss: 0.0000 | G_loss: 32.1363
# Iter 900 | D_loss: 0.0000 | G_loss: 21.4407
# Epoch 45
# Iter 0 | D_loss: 0.0000 | G_loss: 21.1275
# Iter 100 | D_loss: 0.0000 | G_loss: 21.4791
# Iter 200 | D_loss: 0.0000 | G_loss: 46.9900
# Iter 300 | D_loss: 0.0000 | G_loss: 20.6090
# Iter 400 | D_loss: 0.0000 | G_loss: 41.6014
# Iter 500 | D_loss: 0.0000 | G_loss: 17.1392
# Iter 600 | D_loss: 0.0000 | G_loss: 17.4757
# Iter 700 | D_loss: 0.0000 | G_loss: 18.7554
# Iter 800 | D_loss: 0.0000 | G_loss: 17.5675
# Iter 900 | D_loss: 0.0000 | G_loss: 15.1208
# Epoch 46
# Iter 0 | D_loss: 0.0000 | G_loss: 25.4966
# Iter 100 | D_loss: 0.0000 | G_loss: 32.0570
# Iter 200 | D_loss: 0.0000 | G_loss: 20.8928
# Iter 300 | D_loss: 0.0000 | G_loss: 19.7438
# Iter 400 | D_loss: 0.0000 | G_loss: 18.1161
# Iter 500 | D_loss: 0.0000 | G_loss: 77.8815
# Iter 600 | D_loss: 0.0000 | G_loss: 46.6124
# Iter 700 | D_loss: 0.0000 | G_loss: 48.6013
# Iter 800 | D_loss: 0.0000 | G_loss: 24.1138
# Iter 900 | D_loss: 0.0000 | G_loss: 40.4500
# Epoch 47
# Iter 0 | D_loss: 0.0000 | G_loss: 50.9420
# Iter 100 | D_loss: 0.0000 | G_loss: 27.1881
# Iter 200 | D_loss: 0.0002 | G_loss: 16.0523
# Iter 300 | D_loss: 0.0000 | G_loss: 16.2245
# Iter 400 | D_loss: 0.0000 | G_loss: 24.5676
# Iter 500 | D_loss: 0.0000 | G_loss: 17.4901
# Iter 600 | D_loss: 0.0000 | G_loss: 34.0730
# Iter 700 | D_loss: 0.0000 | G_loss: 19.7668
# Iter 800 | D_loss: 0.0000 | G_loss: 21.4153
# Iter 900 | D_loss: 0.0000 | G_loss: 18.8089
# Epoch 48
# Iter 0 | D_loss: 0.0000 | G_loss: 36.9086
# Iter 100 | D_loss: 0.0000 | G_loss: 31.3017
# Iter 200 | D_loss: 0.0000 | G_loss: 24.0099
# Iter 300 | D_loss: 0.0000 | G_loss: 29.9690
# Iter 400 | D_loss: 0.0000 | G_loss: 20.4313
# Iter 500 | D_loss: 0.0000 | G_loss: 19.8232
# Iter 600 | D_loss: 0.0000 | G_loss: 19.1836
# Iter 700 | D_loss: 0.0000 | G_loss: 21.3296
# Iter 800 | D_loss: 0.0000 | G_loss: 29.2848
# Iter 900 | D_loss: 0.0000 | G_loss: 17.0639
# Epoch 49
# Iter 0 | D_loss: 0.0000 | G_loss: 19.7336
# Iter 100 | D_loss: 0.0000 | G_loss: 16.9596
# Iter 200 | D_loss: 0.0000 | G_loss: 17.6950
# Iter 300 | D_loss: 0.0000 | G_loss: 26.7637
# Iter 400 | D_loss: 0.0000 | G_loss: 29.5726
# Iter 500 | D_loss: 0.0000 | G_loss: 40.4297
# Iter 600 | D_loss: 0.0000 | G_loss: 20.6973
# Iter 700 | D_loss: 0.0000 | G_loss: 24.8098
# Iter 800 | D_loss: 0.0000 | G_loss: 22.7861
# Iter 900 | D_loss: 0.0000 | G_loss: 25.7817
# Epoch 50
# Iter 0 | D_loss: 0.0002 | G_loss: 18.4688
# Iter 100 | D_loss: 0.0000 | G_loss: 35.3722
# Iter 200 | D_loss: 0.0000 | G_loss: 25.7509
# Iter 300 | D_loss: 0.0000 | G_loss: 19.1151
# Iter 400 | D_loss: 0.0000 | G_loss: 18.2647
# Iter 500 | D_loss: 0.0000 | G_loss: 16.9056
# Iter 600 | D_loss: 0.0000 | G_loss: 18.2879
# Iter 700 | D_loss: 0.0000 | G_loss: 17.9334
# Iter 800 | D_loss: 0.0000 | G_loss: 19.8002
# Iter 900 | D_loss: 0.0000 | G_loss: 16.4701
# Epoch 51
# Iter 0 | D_loss: 0.0000 | G_loss: 18.4829
# Iter 100 | D_loss: 0.0000 | G_loss: 17.5726
# Iter 200 | D_loss: 0.0000 | G_loss: 17.3913
# Iter 300 | D_loss: 0.0000 | G_loss: 18.1057
# Iter 400 | D_loss: 0.0000 | G_loss: 17.9704
# Iter 500 | D_loss: 0.0000 | G_loss: 21.3521
# Iter 600 | D_loss: 0.0000 | G_loss: 20.3830
# Iter 700 | D_loss: 0.0000 | G_loss: 21.0381
# Iter 800 | D_loss: 0.0000 | G_loss: 21.3272
# Iter 900 | D_loss: 0.0000 | G_loss: 19.6671
# Epoch 52
# Iter 0 | D_loss: 0.0000 | G_loss: 19.8207
# Iter 100 | D_loss: 0.0000 | G_loss: 19.9586
# Iter 200 | D_loss: 0.0000 | G_loss: 19.2209
# Iter 300 | D_loss: 0.0000 | G_loss: 17.9509
# Iter 400 | D_loss: 0.0000 | G_loss: 52.1667
# Iter 500 | D_loss: 0.0000 | G_loss: 17.4666
# Iter 600 | D_loss: 0.0000 | G_loss: 18.6454
# Iter 700 | D_loss: 0.0000 | G_loss: 16.8730
# Iter 800 | D_loss: 0.0000 | G_loss: 20.1453
# Iter 900 | D_loss: 0.0000 | G_loss: 19.9232
# Epoch 53
# Iter 0 | D_loss: 0.0000 | G_loss: 19.0598
# Iter 100 | D_loss: 0.0000 | G_loss: 20.2689
# Iter 200 | D_loss: 0.0000 | G_loss: 20.3299
# Iter 300 | D_loss: 0.0000 | G_loss: 19.4128
# Iter 400 | D_loss: 0.0000 | G_loss: 20.8552
# Iter 500 | D_loss: 0.0000 | G_loss: 18.7173
# Iter 600 | D_loss: 0.0000 | G_loss: 21.9027
# Iter 700 | D_loss: 0.0000 | G_loss: 21.7672
# Iter 800 | D_loss: 0.0000 | G_loss: 19.8340
# Iter 900 | D_loss: 0.0000 | G_loss: 20.9098
# Epoch 54
# Iter 0 | D_loss: 0.0000 | G_loss: 66.8419
# Iter 100 | D_loss: 0.0000 | G_loss: 20.6141
# Iter 200 | D_loss: 0.0000 | G_loss: 28.9475
# Iter 300 | D_loss: 0.0000 | G_loss: 66.8375
# Iter 400 | D_loss: 0.0000 | G_loss: 21.9967
# Iter 500 | D_loss: 0.0000 | G_loss: 49.5850
# Iter 600 | D_loss: 0.0000 | G_loss: 23.2721
# Iter 700 | D_loss: 0.0000 | G_loss: 21.3374
# Iter 800 | D_loss: 0.0000 | G_loss: 19.9423
# Iter 900 | D_loss: 0.0000 | G_loss: 18.8326
# Epoch 55
# Iter 0 | D_loss: 0.0000 | G_loss: 22.8195
# Iter 100 | D_loss: 0.0000 | G_loss: 17.9904
# Iter 200 | D_loss: 0.0000 | G_loss: 27.4676
# Iter 300 | D_loss: 0.0000 | G_loss: 65.6290
# Iter 400 | D_loss: 0.0000 | G_loss: 24.0482
# Iter 500 | D_loss: 0.0000 | G_loss: 55.6405
# Iter 600 | D_loss: 0.0000 | G_loss: 19.2655
# Iter 700 | D_loss: 0.0000 | G_loss: 28.7082
# Iter 800 | D_loss: 0.0000 | G_loss: 22.8254
# Iter 900 | D_loss: 0.0000 | G_loss: 17.9901
# Epoch 56
# Iter 0 | D_loss: 0.0000 | G_loss: 18.4867
# Iter 100 | D_loss: 0.0000 | G_loss: 32.4398
# Iter 200 | D_loss: 0.0000 | G_loss: 20.6239
# Iter 300 | D_loss: 0.0000 | G_loss: 18.4776
# Iter 400 | D_loss: 0.0000 | G_loss: 20.5991
# Iter 500 | D_loss: 0.0000 | G_loss: 20.5325
# Iter 600 | D_loss: 0.0000 | G_loss: 16.0894
# Iter 700 | D_loss: 0.0000 | G_loss: 19.3078
# Iter 800 | D_loss: 0.0000 | G_loss: 17.7333
# Iter 900 | D_loss: 0.0000 | G_loss: 17.7185
# Epoch 57
# Iter 0 | D_loss: 0.0000 | G_loss: 17.8869
# Iter 100 | D_loss: 0.0000 | G_loss: 18.9640
# Iter 200 | D_loss: 0.0000 | G_loss: 18.3853
# Iter 300 | D_loss: 0.0000 | G_loss: 19.6802
# Iter 400 | D_loss: 0.0000 | G_loss: 18.0452
# Iter 500 | D_loss: 0.0000 | G_loss: 19.3886
# Iter 600 | D_loss: 0.0000 | G_loss: 22.3213
# Iter 700 | D_loss: 0.0000 | G_loss: 19.0545
# Iter 800 | D_loss: 0.0000 | G_loss: 23.1070
# Iter 900 | D_loss: 0.0000 | G_loss: 21.4160
# Epoch 58
# Iter 0 | D_loss: 0.0000 | G_loss: 21.1759
# Iter 100 | D_loss: 0.0000 | G_loss: 22.0746
# Iter 200 | D_loss: 0.0000 | G_loss: 20.9292
# Iter 300 | D_loss: 0.0000 | G_loss: 50.9426
# Iter 400 | D_loss: 0.0000 | G_loss: 22.7625
# Iter 500 | D_loss: 0.0000 | G_loss: 23.4176
# Iter 600 | D_loss: 0.0000 | G_loss: 25.2504
# Iter 700 | D_loss: 0.0000 | G_loss: 18.8055
# Iter 800 | D_loss: 0.0001 | G_loss: 20.1497
# Iter 900 | D_loss: 0.0000 | G_loss: 44.5440
# Epoch 59
# Iter 0 | D_loss: 0.0000 | G_loss: 24.6802
# Iter 100 | D_loss: 0.0000 | G_loss: 24.2548
# Iter 200 | D_loss: 0.0000 | G_loss: 15.8243
# Iter 300 | D_loss: 0.0000 | G_loss: 23.8074
# Iter 400 | D_loss: 0.0000 | G_loss: 25.7381
# Iter 500 | D_loss: 0.0000 | G_loss: 22.4813
# Iter 600 | D_loss: 0.0000 | G_loss: 36.3783
# Iter 700 | D_loss: 0.0000 | G_loss: 53.1813
# Iter 800 | D_loss: 0.0000 | G_loss: 49.3919
# Iter 900 | D_loss: 0.0000 | G_loss: 31.4311
# Epoch 60
# Iter 0 | D_loss: 0.0000 | G_loss: 25.0535
# Iter 100 | D_loss: 0.0000 | G_loss: 23.7747
# Iter 200 | D_loss: 0.0000 | G_loss: 18.6826
# Iter 300 | D_loss: 0.0000 | G_loss: 33.5160
# Iter 400 | D_loss: 0.0000 | G_loss: 49.7882
# Iter 500 | D_loss: 0.0000 | G_loss: 45.5378
# Iter 600 | D_loss: 0.0000 | G_loss: 22.9430
# Iter 700 | D_loss: 0.0000 | G_loss: 39.6920
# Iter 800 | D_loss: 0.0000 | G_loss: 25.6465
# Iter 900 | D_loss: 0.0000 | G_loss: 27.8952
# Epoch 61
# Iter 0 | D_loss: 0.0000 | G_loss: 19.3319
# Iter 100 | D_loss: 0.0000 | G_loss: 18.8550
# Iter 200 | D_loss: 0.0000 | G_loss: 19.0675
# Iter 300 | D_loss: 0.0000 | G_loss: 19.6692
# Iter 400 | D_loss: 0.0000 | G_loss: 81.2722
# Iter 500 | D_loss: 0.0000 | G_loss: 31.2130
# Iter 600 | D_loss: 0.0000 | G_loss: 38.6740
# Iter 700 | D_loss: 0.0000 | G_loss: 28.3555
# Iter 800 | D_loss: 0.0000 | G_loss: 19.1970
# Iter 900 | D_loss: 0.0000 | G_loss: 58.1272
# Epoch 62
# Iter 0 | D_loss: 0.0000 | G_loss: 47.9660
# Iter 100 | D_loss: 0.0000 | G_loss: 25.4728
# Iter 200 | D_loss: 0.0000 | G_loss: 38.8594
# Iter 300 | D_loss: 0.0000 | G_loss: 23.8025
# Iter 400 | D_loss: 0.0000 | G_loss: 21.5217
# Iter 500 | D_loss: 0.0000 | G_loss: 15.0305
# Iter 600 | D_loss: 0.0000 | G_loss: 66.7312
# Iter 700 | D_loss: 0.0000 | G_loss: 37.5216
# Iter 800 | D_loss: 0.0000 | G_loss: 34.5291
# Iter 900 | D_loss: 0.0000 | G_loss: 29.4195
# Epoch 63
# Iter 0 | D_loss: 0.0000 | G_loss: 15.5003
# Iter 100 | D_loss: 0.0000 | G_loss: 23.9667
# Iter 200 | D_loss: 0.0000 | G_loss: 49.7374
# Iter 300 | D_loss: 0.0000 | G_loss: 28.1094
# Iter 400 | D_loss: 0.0000 | G_loss: 25.0196
# Iter 500 | D_loss: 0.0000 | G_loss: 81.5878
# Iter 600 | D_loss: 0.0000 | G_loss: 33.4112
# Iter 700 | D_loss: 0.0000 | G_loss: 28.5306
# Iter 800 | D_loss: 0.0000 | G_loss: 51.0265
# Iter 900 | D_loss: 0.0000 | G_loss: 30.6475
# Epoch 64
# Iter 0 | D_loss: 0.0000 | G_loss: 25.8516
# Iter 100 | D_loss: 0.0000 | G_loss: 20.7213
# Iter 200 | D_loss: 0.0000 | G_loss: 40.5256
# Iter 300 | D_loss: 0.0000 | G_loss: 35.8430
# Iter 400 | D_loss: 0.0000 | G_loss: 26.1294
# Iter 500 | D_loss: 0.0000 | G_loss: 20.0999
# Iter 600 | D_loss: 0.0000 | G_loss: 19.8443
# Iter 700 | D_loss: 0.0000 | G_loss: 22.7593
# Iter 800 | D_loss: 0.0000 | G_loss: 23.1569
# Iter 900 | D_loss: 0.0000 | G_loss: 23.7713
# Epoch 65
# Iter 0 | D_loss: 0.0000 | G_loss: 19.7836
# Iter 100 | D_loss: 0.0000 | G_loss: 21.2893
# Iter 200 | D_loss: 0.0000 | G_loss: 19.9873
# Iter 300 | D_loss: 0.0000 | G_loss: 30.8690
# Iter 400 | D_loss: 0.0000 | G_loss: 103.0857
# Iter 500 | D_loss: 0.0000 | G_loss: 32.3788
# Iter 600 | D_loss: 0.0001 | G_loss: 16.6844
# Iter 700 | D_loss: 0.0000 | G_loss: 18.4693
# Iter 800 | D_loss: 0.0000 | G_loss: 20.5579
# Iter 900 | D_loss: 0.0000 | G_loss: 20.5886
# Epoch 66
# Iter 0 | D_loss: 0.0000 | G_loss: 22.0230
# Iter 100 | D_loss: 0.0000 | G_loss: 18.5875
# Iter 200 | D_loss: 0.0000 | G_loss: 27.3104
# Iter 300 | D_loss: 0.0000 | G_loss: 22.3350
# Iter 400 | D_loss: 0.0001 | G_loss: 35.7579
# Iter 500 | D_loss: 0.0000 | G_loss: 18.1343
# Iter 600 | D_loss: 0.0000 | G_loss: 34.2670
# Iter 700 | D_loss: 0.0000 | G_loss: 28.1557
# Iter 800 | D_loss: 0.0000 | G_loss: 30.4094
# Iter 900 | D_loss: 0.0002 | G_loss: 20.0962
# Epoch 67
# Iter 0 | D_loss: 0.0000 | G_loss: 23.0930
# Iter 100 | D_loss: 0.0000 | G_loss: 35.8656
# Iter 200 | D_loss: 0.0000 | G_loss: 20.9253
# Iter 300 | D_loss: 0.0001 | G_loss: 18.8132
# Iter 400 | D_loss: 0.0000 | G_loss: 61.8977
# Iter 500 | D_loss: 0.0000 | G_loss: 32.2783
# Iter 600 | D_loss: 0.0000 | G_loss: 23.3912
# Iter 700 | D_loss: 0.0000 | G_loss: 24.6446
# Iter 800 | D_loss: 0.0000 | G_loss: 30.8285
# Iter 900 | D_loss: 0.0000 | G_loss: 17.3197
# Epoch 68
# Iter 0 | D_loss: 0.0000 | G_loss: 15.2852
# Iter 100 | D_loss: 0.0000 | G_loss: 61.3086
# Iter 200 | D_loss: 0.0000 | G_loss: 21.7756
# Iter 300 | D_loss: 0.0000 | G_loss: 19.3961
# Iter 400 | D_loss: 0.0000 | G_loss: 26.5561
# Iter 500 | D_loss: 0.0000 | G_loss: 28.3666
# Iter 600 | D_loss: 0.0000 | G_loss: 22.4204
# Iter 700 | D_loss: 0.0000 | G_loss: 18.6984
# Iter 800 | D_loss: 0.0000 | G_loss: 18.0187
# Iter 900 | D_loss: 0.0000 | G_loss: 26.9163
# Epoch 69
# Iter 0 | D_loss: 0.0000 | G_loss: 37.6524
# Iter 100 | D_loss: 0.0000 | G_loss: 46.5809
# Iter 200 | D_loss: 0.0000 | G_loss: 31.0216
# Iter 300 | D_loss: 0.0000 | G_loss: 21.2116
# Iter 400 | D_loss: 0.0000 | G_loss: 19.3346
# Iter 500 | D_loss: 0.0000 | G_loss: 21.3817
# Iter 600 | D_loss: 0.0000 | G_loss: 20.5546
# Iter 700 | D_loss: 0.0000 | G_loss: 20.1765
# Iter 800 | D_loss: 0.0000 | G_loss: 25.1402
# Iter 900 | D_loss: 0.0000 | G_loss: 21.6664
# Epoch 70
# Iter 0 | D_loss: 0.0000 | G_loss: 23.0946
# Iter 100 | D_loss: 0.0000 | G_loss: 21.0311
# Iter 200 | D_loss: 0.0000 | G_loss: 19.7296
# Iter 300 | D_loss: 0.0000 | G_loss: 19.3274
# Iter 400 | D_loss: 0.0000 | G_loss: 29.5735
# Iter 500 | D_loss: 0.0000 | G_loss: 21.7672
# Iter 600 | D_loss: 0.0000 | G_loss: 20.6934
# Iter 700 | D_loss: 0.0000 | G_loss: 30.7892
# Iter 800 | D_loss: 0.0000 | G_loss: 19.7364
# Iter 900 | D_loss: 0.0000 | G_loss: 18.2552
# Epoch 71
# Iter 0 | D_loss: 0.0000 | G_loss: 20.5780
# Iter 100 | D_loss: 0.0000 | G_loss: 20.5755
# Iter 200 | D_loss: 0.0000 | G_loss: 21.1921
# Iter 300 | D_loss: 0.0000 | G_loss: 19.1894
# Iter 400 | D_loss: 0.0000 | G_loss: 16.9272
# Iter 500 | D_loss: 0.0000 | G_loss: 18.7236
# Iter 600 | D_loss: 0.0000 | G_loss: 20.0578
# Iter 700 | D_loss: 0.0000 | G_loss: 18.9880
# Iter 800 | D_loss: 0.0000 | G_loss: 17.7448
# Iter 900 | D_loss: 0.0000 | G_loss: 20.0615
# Epoch 72
# Iter 0 | D_loss: 0.0000 | G_loss: 21.0772
# Iter 100 | D_loss: 0.0000 | G_loss: 18.4590
# Iter 200 | D_loss: 0.0000 | G_loss: 28.9136
# Iter 300 | D_loss: 0.0000 | G_loss: 35.2796
# Iter 400 | D_loss: 0.0000 | G_loss: 26.3492
# Iter 500 | D_loss: 0.0000 | G_loss: 18.8049
# Iter 600 | D_loss: 0.0000 | G_loss: 22.5581
# Iter 700 | D_loss: 0.0000 | G_loss: 47.2438
# Iter 800 | D_loss: 0.0000 | G_loss: 34.2078
# Iter 900 | D_loss: 0.0012 | G_loss: 12.1772
# Epoch 73
# Iter 0 | D_loss: 0.0000 | G_loss: 21.5821
# Iter 100 | D_loss: 0.0000 | G_loss: 22.9990
# Iter 200 | D_loss: 0.0000 | G_loss: 19.1557
# Iter 300 | D_loss: 0.0000 | G_loss: 40.2622
# Iter 400 | D_loss: 0.0000 | G_loss: 24.7774
# Iter 500 | D_loss: 0.0000 | G_loss: 22.8510
# Iter 600 | D_loss: 0.0000 | G_loss: 23.1131
# Iter 700 | D_loss: 0.0000 | G_loss: 24.9974
# Iter 800 | D_loss: 0.0000 | G_loss: 23.8189
# Iter 900 | D_loss: 0.0000 | G_loss: 25.9373
# Epoch 74
# Iter 0 | D_loss: 0.0000 | G_loss: 19.6713
# Iter 100 | D_loss: 0.0000 | G_loss: 23.0443
# Iter 200 | D_loss: 0.0000 | G_loss: 24.1405
# Iter 300 | D_loss: 0.0000 | G_loss: 29.9110
# Iter 400 | D_loss: 0.0000 | G_loss: 26.3468
# Iter 500 | D_loss: 0.0000 | G_loss: 26.0636
# Iter 600 | D_loss: 0.0000 | G_loss: 20.2050
# Iter 700 | D_loss: 0.0000 | G_loss: 18.3579
# Iter 800 | D_loss: 0.0000 | G_loss: 19.9702
# Iter 900 | D_loss: 0.0000 | G_loss: 21.9998
# Epoch 75
# Iter 0 | D_loss: 0.0001 | G_loss: 15.7554
# Iter 100 | D_loss: 0.0000 | G_loss: 23.9118
# Iter 200 | D_loss: 0.0000 | G_loss: 19.4374
# Iter 300 | D_loss: 0.0000 | G_loss: 20.3259
# Iter 400 | D_loss: 0.0000 | G_loss: 19.7973
# Iter 500 | D_loss: 0.0000 | G_loss: 18.8855
# Iter 600 | D_loss: 0.0000 | G_loss: 17.4846
# Iter 700 | D_loss: 0.0000 | G_loss: 20.2430
# Iter 800 | D_loss: 0.0000 | G_loss: 19.8530
# Iter 900 | D_loss: 0.0000 | G_loss: 58.2494
# Epoch 76
# Iter 0 | D_loss: 0.0000 | G_loss: 34.0344
# Iter 100 | D_loss: 0.0000 | G_loss: 23.4235
# Iter 200 | D_loss: 0.0000 | G_loss: 22.4991
# Iter 300 | D_loss: 0.0000 | G_loss: 19.9653
# Iter 400 | D_loss: 0.0000 | G_loss: 19.2506
# Iter 500 | D_loss: 0.0000 | G_loss: 20.7267
# Iter 600 | D_loss: 0.0000 | G_loss: 21.7959
# Iter 700 | D_loss: 0.0000 | G_loss: 21.4004
# Iter 800 | D_loss: 0.0000 | G_loss: 22.2133
# Iter 900 | D_loss: 0.0000 | G_loss: 25.3001
# Epoch 77
# Iter 0 | D_loss: 0.0000 | G_loss: 23.1743
# Iter 100 | D_loss: 0.0000 | G_loss: 20.7488
# Iter 200 | D_loss: 0.0000 | G_loss: 21.7364
# Iter 300 | D_loss: 0.0000 | G_loss: 23.0449
# Iter 400 | D_loss: 0.0000 | G_loss: 23.7493
# Iter 500 | D_loss: 0.0000 | G_loss: 22.9547
# Iter 600 | D_loss: 0.0000 | G_loss: 22.9524
# Iter 700 | D_loss: 0.0000 | G_loss: 23.5230
# Iter 800 | D_loss: 0.0000 | G_loss: 24.6770
# Iter 900 | D_loss: 0.0000 | G_loss: 23.2830
# Epoch 78
# Iter 0 | D_loss: 0.0000 | G_loss: 22.6685
# Iter 100 | D_loss: 0.0000 | G_loss: 23.1752
# Iter 200 | D_loss: 0.0000 | G_loss: 22.6154
# Iter 300 | D_loss: 0.0000 | G_loss: 25.0247
# Iter 400 | D_loss: 0.0000 | G_loss: 24.8873
# Iter 500 | D_loss: 0.0000 | G_loss: 24.6451
# Iter 600 | D_loss: 0.0000 | G_loss: 25.3631
# Iter 700 | D_loss: 0.0000 | G_loss: 24.7089
# Iter 800 | D_loss: 0.0000 | G_loss: 25.0665
# Iter 900 | D_loss: 0.0000 | G_loss: 56.7335
# Epoch 79
# Iter 0 | D_loss: 0.0000 | G_loss: 51.3196
# Iter 100 | D_loss: 0.0000 | G_loss: 41.5845
# Iter 200 | D_loss: 0.0000 | G_loss: 26.6985
# Iter 300 | D_loss: 0.0000 | G_loss: 36.5593
# Iter 400 | D_loss: 0.0000 | G_loss: 27.4213
# Iter 500 | D_loss: 0.0000 | G_loss: 33.1908
# Iter 600 | D_loss: 0.0000 | G_loss: 27.7501
# Iter 700 | D_loss: 0.0000 | G_loss: 23.6350
# Iter 800 | D_loss: 0.0000 | G_loss: 27.6359
# Iter 900 | D_loss: 0.0000 | G_loss: 26.1716
# Epoch 80
# Iter 0 | D_loss: 0.0000 | G_loss: 25.0050
# Iter 100 | D_loss: 0.0000 | G_loss: 25.3846
# Iter 200 | D_loss: 0.0000 | G_loss: 26.2100
# Iter 300 | D_loss: 0.0000 | G_loss: 30.5221
# Iter 400 | D_loss: 0.0000 | G_loss: 25.6920
# Iter 500 | D_loss: 0.0000 | G_loss: 25.3758
# Iter 600 | D_loss: 0.0000 | G_loss: 25.6204
# Iter 700 | D_loss: 0.0000 | G_loss: 26.0254
# Iter 800 | D_loss: 0.0000 | G_loss: 25.6687
# Iter 900 | D_loss: 0.0000 | G_loss: 131.7372
# Epoch 81
# Iter 0 | D_loss: 0.0000 | G_loss: 130.3357
# Iter 100 | D_loss: 0.0000 | G_loss: 76.6630
# Iter 200 | D_loss: 0.0000 | G_loss: 46.6523
# Iter 300 | D_loss: 0.0000 | G_loss: 20.3874
# Iter 400 | D_loss: 0.0000 | G_loss: 23.7708
# Iter 500 | D_loss: 0.0000 | G_loss: 19.7329
# Iter 600 | D_loss: 0.0000 | G_loss: 27.0506
# Iter 700 | D_loss: 0.0000 | G_loss: 19.9559
# Iter 800 | D_loss: 0.0000 | G_loss: 19.4583
# Iter 900 | D_loss: 0.0000 | G_loss: 18.2036
# Epoch 82
# Iter 0 | D_loss: 0.0000 | G_loss: 20.9910
# Iter 100 | D_loss: 0.0000 | G_loss: 26.6206
# Iter 200 | D_loss: 0.0000 | G_loss: 69.8324
# Iter 300 | D_loss: 0.0000 | G_loss: 19.7570
# Iter 400 | D_loss: 0.0000 | G_loss: 24.7211
# Iter 500 | D_loss: 0.0000 | G_loss: 21.3538
# Iter 600 | D_loss: 0.0000 | G_loss: 26.7518
# Iter 700 | D_loss: 0.0000 | G_loss: 33.0923
# Iter 800 | D_loss: 0.0001 | G_loss: 22.5952
# Iter 900 | D_loss: 0.0000 | G_loss: 49.6115
# Epoch 83
# Iter 0 | D_loss: 0.0000 | G_loss: 30.2199
# Iter 100 | D_loss: 0.0000 | G_loss: 18.4465
# Iter 200 | D_loss: 0.0000 | G_loss: 64.4470
# Iter 300 | D_loss: 0.0000 | G_loss: 19.7777
# Iter 400 | D_loss: 0.0000 | G_loss: 30.3544
# Iter 500 | D_loss: 0.0000 | G_loss: 84.2347
# Iter 600 | D_loss: 0.0000 | G_loss: 21.6741
# Iter 700 | D_loss: 0.0000 | G_loss: 22.1614
# Iter 800 | D_loss: 0.0000 | G_loss: 18.8787
# Iter 900 | D_loss: 0.0000 | G_loss: 18.0755
# Epoch 84
# Iter 0 | D_loss: 0.0000 | G_loss: 17.9084
# Iter 100 | D_loss: 0.0000 | G_loss: 44.6508
# Iter 200 | D_loss: 0.0000 | G_loss: 68.4695
# Iter 300 | D_loss: 0.0000 | G_loss: 30.6424
# Iter 400 | D_loss: 0.0000 | G_loss: 35.3444
# Iter 500 | D_loss: 0.0000 | G_loss: 55.1212
# Iter 600 | D_loss: 0.0000 | G_loss: 36.5645
# Iter 700 | D_loss: 0.0000 | G_loss: 35.4251
# Iter 800 | D_loss: 0.0000 | G_loss: 74.4148
# Iter 900 | D_loss: 0.0000 | G_loss: 51.8719
# Epoch 85
# Iter 0 | D_loss: 0.0000 | G_loss: 19.9662
# Iter 100 | D_loss: 0.0000 | G_loss: 20.2768
# Iter 200 | D_loss: 0.0000 | G_loss: 29.6944
# Iter 300 | D_loss: 0.0000 | G_loss: 50.9618
# Iter 400 | D_loss: 0.0000 | G_loss: 88.9278
# Iter 500 | D_loss: 0.0000 | G_loss: 69.3508
# Iter 600 | D_loss: 0.0000 | G_loss: 53.9848
# Iter 700 | D_loss: 0.0000 | G_loss: 37.4154
# Iter 800 | D_loss: 0.0000 | G_loss: 23.9558
# Iter 900 | D_loss: 0.0000 | G_loss: 47.7879
# Epoch 86
# Iter 0 | D_loss: 0.0000 | G_loss: 34.0154
# Iter 100 | D_loss: 0.0000 | G_loss: 45.6349
# Iter 200 | D_loss: 0.0000 | G_loss: 33.0844
# Iter 300 | D_loss: 0.0000 | G_loss: 24.7077
# Iter 400 | D_loss: 0.0064 | G_loss: 19.3718
# Iter 500 | D_loss: 0.0000 | G_loss: 49.7984
# Iter 600 | D_loss: 0.0000 | G_loss: 17.1722
# Iter 700 | D_loss: 0.0000 | G_loss: 20.9294
# Iter 800 | D_loss: 0.0000 | G_loss: 18.6653
# Iter 900 | D_loss: 0.0000 | G_loss: 16.2876
# Epoch 87
# Iter 0 | D_loss: 0.0000 | G_loss: 38.1456
# Iter 100 | D_loss: 0.0000 | G_loss: 32.5494
# Iter 200 | D_loss: 0.0000 | G_loss: 28.4631
# Iter 300 | D_loss: 0.0000 | G_loss: 21.6946
# Iter 400 | D_loss: 0.0000 | G_loss: 23.6349
# Iter 500 | D_loss: 0.0000 | G_loss: 20.4201
# Iter 600 | D_loss: 0.0000 | G_loss: 18.9945
# Iter 700 | D_loss: 0.0000 | G_loss: 17.9507
# Iter 800 | D_loss: 0.0000 | G_loss: 18.4815
# Iter 900 | D_loss: 0.0000 | G_loss: 18.1885
# Epoch 88
# Iter 0 | D_loss: 0.0000 | G_loss: 21.8526
# Iter 100 | D_loss: 0.0000 | G_loss: 24.5624
# Iter 200 | D_loss: 0.0000 | G_loss: 87.6397
# Iter 300 | D_loss: 0.0000 | G_loss: 21.3054
# Iter 400 | D_loss: 0.0000 | G_loss: 26.6261
# Iter 500 | D_loss: 0.0000 | G_loss: 21.0857
# Iter 600 | D_loss: 0.0000 | G_loss: 30.8204
# Iter 700 | D_loss: 0.0000 | G_loss: 26.3786
# Iter 800 | D_loss: 0.0000 | G_loss: 27.2587
# Iter 900 | D_loss: 0.0000 | G_loss: 21.0636
# Epoch 89
# Iter 0 | D_loss: 0.0000 | G_loss: 20.6219
# Iter 100 | D_loss: 0.0000 | G_loss: 22.3721
# Iter 200 | D_loss: 0.0000 | G_loss: 25.7782
# Iter 300 | D_loss: 0.0014 | G_loss: 123.9215
# Iter 400 | D_loss: 0.0000 | G_loss: 28.1210
# Iter 500 | D_loss: 0.0000 | G_loss: 34.1802
# Iter 600 | D_loss: 0.0000 | G_loss: 26.6795
# Iter 700 | D_loss: 0.0000 | G_loss: 40.0168
# Iter 800 | D_loss: 0.0000 | G_loss: 23.9929
# Iter 900 | D_loss: 0.0000 | G_loss: 35.2554
# Epoch 90
# Iter 0 | D_loss: 0.0000 | G_loss: 18.7609
# Iter 100 | D_loss: 0.0000 | G_loss: 20.3733
# Iter 200 | D_loss: 0.0000 | G_loss: 34.5888
# Iter 300 | D_loss: 0.0000 | G_loss: 18.9735
# Iter 400 | D_loss: 0.0000 | G_loss: 34.2689
# Iter 500 | D_loss: 0.0000 | G_loss: 16.6155
# Iter 600 | D_loss: 0.0000 | G_loss: 18.7612
# Iter 700 | D_loss: 0.0000 | G_loss: 29.3434
# Iter 800 | D_loss: 0.0000 | G_loss: 13.6487
# Iter 900 | D_loss: 0.0000 | G_loss: 31.8301
# Epoch 91
# Iter 0 | D_loss: 0.0000 | G_loss: 28.6793
# Iter 100 | D_loss: 0.0000 | G_loss: 20.0224
# Iter 200 | D_loss: 0.0000 | G_loss: 21.7113
# Iter 300 | D_loss: 0.0000 | G_loss: 17.9798
# Iter 400 | D_loss: 0.0000 | G_loss: 22.4220
# Iter 500 | D_loss: 0.0000 | G_loss: 16.0918
# Iter 600 | D_loss: 0.0000 | G_loss: 19.4471
# Iter 700 | D_loss: 0.0229 | G_loss: 12.6630
# Iter 800 | D_loss: 0.0000 | G_loss: 24.0956
# Iter 900 | D_loss: 0.0000 | G_loss: 36.0073
# Epoch 92
# Iter 0 | D_loss: 0.0000 | G_loss: 24.3358
# Iter 100 | D_loss: 0.0000 | G_loss: 38.6637
# Iter 200 | D_loss: 0.0000 | G_loss: 29.5134
# Iter 300 | D_loss: 0.0000 | G_loss: 19.0440
# Iter 400 | D_loss: 0.0000 | G_loss: 19.9152
# Iter 500 | D_loss: 0.0000 | G_loss: 29.2571
# Iter 600 | D_loss: 0.0000 | G_loss: 17.9112
# Iter 700 | D_loss: 0.0000 | G_loss: 22.8897
# Iter 800 | D_loss: 0.0000 | G_loss: 17.7419
# Iter 900 | D_loss: 0.0000 | G_loss: 19.0043
# Epoch 93
# Iter 0 | D_loss: 0.0000 | G_loss: 47.2033
# Iter 100 | D_loss: 0.0000 | G_loss: 33.4537
# Iter 200 | D_loss: 0.0000 | G_loss: 19.8389
# Iter 300 | D_loss: 0.0000 | G_loss: 21.6490
# Iter 400 | D_loss: 0.0000 | G_loss: 16.5126
# Iter 500 | D_loss: 0.0000 | G_loss: 34.2237
# Iter 600 | D_loss: 0.0000 | G_loss: 24.6895
# Iter 700 | D_loss: 0.0000 | G_loss: 20.0534
# Iter 800 | D_loss: 0.0000 | G_loss: 19.0454
# Iter 900 | D_loss: 0.0000 | G_loss: 18.1401
# Epoch 94
# Iter 0 | D_loss: 0.0000 | G_loss: 17.0160
# Iter 100 | D_loss: 0.0000 | G_loss: 15.6835
# Iter 200 | D_loss: 0.0000 | G_loss: 16.6413
# Iter 300 | D_loss: 0.0000 | G_loss: 17.3648
# Iter 400 | D_loss: 0.0000 | G_loss: 17.0182
# Iter 500 | D_loss: 0.0000 | G_loss: 15.4492
# Iter 600 | D_loss: 0.0000 | G_loss: 16.7769
# Iter 700 | D_loss: 0.0000 | G_loss: 17.0124
# Iter 800 | D_loss: 0.0000 | G_loss: 17.2343
# Iter 900 | D_loss: 0.0000 | G_loss: 18.6143
# Epoch 95
# Iter 0 | D_loss: 0.0000 | G_loss: 18.5308
# Iter 100 | D_loss: 0.0000 | G_loss: 20.2769
# Iter 200 | D_loss: 0.0000 | G_loss: 20.1879
# Iter 300 | D_loss: 0.0000 | G_loss: 58.5864
# Iter 400 | D_loss: 0.0000 | G_loss: 15.6403
# Iter 500 | D_loss: 0.0000 | G_loss: 18.4696
# Iter 600 | D_loss: 0.0000 | G_loss: 15.5612
# Iter 700 | D_loss: 0.0000 | G_loss: 16.8347
# Iter 800 | D_loss: 0.0000 | G_loss: 15.1370
# Iter 900 | D_loss: 0.0000 | G_loss: 15.3953
# Epoch 96
# Iter 0 | D_loss: 0.0000 | G_loss: 18.0961
# Iter 100 | D_loss: 0.0000 | G_loss: 16.9045
# Iter 200 | D_loss: 0.0000 | G_loss: 16.3122
# Iter 300 | D_loss: 0.0000 | G_loss: 15.8182
# Iter 400 | D_loss: 0.0000 | G_loss: 16.7702
# Iter 500 | D_loss: 0.0000 | G_loss: 17.5647
# Iter 600 | D_loss: 0.0000 | G_loss: 16.9090
# Iter 700 | D_loss: 0.0000 | G_loss: 16.9191
# Iter 800 | D_loss: 0.0000 | G_loss: 32.4138
# Iter 900 | D_loss: 0.0000 | G_loss: 25.7839
# Epoch 97
# Iter 0 | D_loss: 0.0000 | G_loss: 25.8541
# Iter 100 | D_loss: 0.0000 | G_loss: 20.7298
# Iter 200 | D_loss: 0.0000 | G_loss: 100.1019
# Iter 300 | D_loss: 0.0000 | G_loss: 80.1946
# Iter 400 | D_loss: 0.0000 | G_loss: 48.4682
# Iter 500 | D_loss: 0.0000 | G_loss: 21.9370
# Iter 600 | D_loss: 0.0000 | G_loss: 27.3693
# Iter 700 | D_loss: 0.0000 | G_loss: 20.9838
# Iter 800 | D_loss: 0.0000 | G_loss: 29.3530
# Iter 900 | D_loss: 0.0000 | G_loss: 20.2307
# Epoch 98
# Iter 0 | D_loss: 0.0000 | G_loss: 18.3998
# Iter 100 | D_loss: 0.0000 | G_loss: 20.7851
# Iter 200 | D_loss: 0.0000 | G_loss: 26.0038
# Iter 300 | D_loss: 0.0000 | G_loss: 85.9576
# Iter 400 | D_loss: 0.0000 | G_loss: 43.4749
# Iter 500 | D_loss: 0.0000 | G_loss: 31.6310
# Iter 600 | D_loss: 0.0000 | G_loss: 19.8545
# Iter 700 | D_loss: 0.0000 | G_loss: 27.8649
# Iter 800 | D_loss: 0.0000 | G_loss: 21.7256
# Iter 900 | D_loss: 0.0000 | G_loss: 31.3088
# Epoch 99
# Iter 0 | D_loss: 0.0000 | G_loss: 43.9142
# Iter 100 | D_loss: 0.0000 | G_loss: 24.5929
# Iter 200 | D_loss: 0.0000 | G_loss: 81.2913
# Iter 300 | D_loss: 0.0000 | G_loss: 20.7933
# Iter 400 | D_loss: 0.0000 | G_loss: 32.7399
# Iter 500 | D_loss: 0.0000 | G_loss: 19.0586
# Iter 600 | D_loss: 0.0000 | G_loss: 48.7764
# Iter 700 | D_loss: 0.0000 | G_loss: 25.7064
# Iter 800 | D_loss: 0.0000 | G_loss: 30.1575
# Iter 900 | D_loss: 0.0000 | G_loss: 37.4115
# Epoch 100
# Iter 0 | D_loss: 0.0000 | G_loss: 28.2193
# Iter 100 | D_loss: 0.0000 | G_loss: 25.4443
# Iter 200 | D_loss: 0.0001 | G_loss: 19.7425
# Iter 300 | D_loss: 0.0000 | G_loss: 51.2960
# Iter 400 | D_loss: 0.0000 | G_loss: 21.2371
# Iter 500 | D_loss: 0.0000 | G_loss: 17.1666
# Iter 600 | D_loss: 0.0000 | G_loss: 40.9264
# Iter 700 | D_loss: 0.0000 | G_loss: 23.7457
# Iter 800 | D_loss: 0.0000 | G_loss: 80.6468
# Iter 900 | D_loss: 0.0000 | G_loss: 60.6854
# Epoch 101
# Iter 0 | D_loss: 0.0000 | G_loss: 48.6213
# Iter 100 | D_loss: 0.0102 | G_loss: 26.4005
# Iter 200 | D_loss: 0.0000 | G_loss: 36.9875
# Iter 300 | D_loss: 0.0000 | G_loss: 21.8602
# Iter 400 | D_loss: 0.0000 | G_loss: 22.3474
# Iter 500 | D_loss: 0.0000 | G_loss: 25.7795
# Iter 600 | D_loss: 0.0000 | G_loss: 23.3896
# Iter 700 | D_loss: 0.0000 | G_loss: 21.3611
# Iter 800 | D_loss: 0.0000 | G_loss: 21.2696
# Iter 900 | D_loss: 0.0000 | G_loss: 20.2165
# Epoch 102
# Iter 0 | D_loss: 0.0000 | G_loss: 18.3676
# Iter 100 | D_loss: 0.0000 | G_loss: 17.8811
# Iter 200 | D_loss: 0.0000 | G_loss: 17.2772
# Iter 300 | D_loss: 0.0000 | G_loss: 26.1713
# Iter 400 | D_loss: 0.0000 | G_loss: 21.0104
# Iter 500 | D_loss: 0.0000 | G_loss: 19.8585
# Iter 600 | D_loss: 0.0000 | G_loss: 27.5473
# Iter 700 | D_loss: 0.0000 | G_loss: 20.6751
# Iter 800 | D_loss: 0.0000 | G_loss: 23.4771
# Iter 900 | D_loss: 0.0000 | G_loss: 79.3174
# Epoch 103
# Iter 0 | D_loss: 0.0000 | G_loss: 57.7208
# Iter 100 | D_loss: 0.0000 | G_loss: 29.6013
# Iter 200 | D_loss: 0.0000 | G_loss: 18.0959
# Iter 300 | D_loss: 0.0000 | G_loss: 17.4036
# Iter 400 | D_loss: 0.0000 | G_loss: 20.4036
# Iter 500 | D_loss: 0.0000 | G_loss: 20.3737
# Iter 600 | D_loss: 0.0032 | G_loss: 14.1659
# Iter 700 | D_loss: 0.0003 | G_loss: 21.5129
# Iter 800 | D_loss: 0.0000 | G_loss: 17.6430
# Iter 900 | D_loss: 0.0000 | G_loss: 17.3249
# Epoch 104
# Iter 0 | D_loss: 0.0000 | G_loss: 17.9667
# Iter 100 | D_loss: 0.0000 | G_loss: 18.3190
# Iter 200 | D_loss: 0.0000 | G_loss: 16.8688
# Iter 300 | D_loss: 0.0000 | G_loss: 16.8550
# Iter 400 | D_loss: 0.0000 | G_loss: 29.6437
# Iter 500 | D_loss: 0.0000 | G_loss: 16.0433
# Iter 600 | D_loss: 0.0000 | G_loss: 17.3753
# Iter 700 | D_loss: 0.0000 | G_loss: 19.3748
# Iter 800 | D_loss: 0.0000 | G_loss: 19.1039
# Iter 900 | D_loss: 0.0000 | G_loss: 126.5123
# Epoch 105
# Iter 0 | D_loss: 0.0000 | G_loss: 76.4131
# Iter 100 | D_loss: 0.0000 | G_loss: 35.9540
# Iter 200 | D_loss: 0.0000 | G_loss: 29.0908
# Iter 300 | D_loss: 0.0000 | G_loss: 38.6848
# Iter 400 | D_loss: 0.0000 | G_loss: 35.3173
# Iter 500 | D_loss: 0.0000 | G_loss: 17.4554
# Iter 600 | D_loss: 0.0000 | G_loss: 17.8552
# Iter 700 | D_loss: 0.0000 | G_loss: 22.0383
# Iter 800 | D_loss: 0.0000 | G_loss: 26.4101
# Iter 900 | D_loss: 0.0000 | G_loss: 17.0917
# Epoch 106
# Iter 0 | D_loss: 0.0000 | G_loss: 15.7125
# Iter 100 | D_loss: 0.0000 | G_loss: 17.3629
# Iter 200 | D_loss: 0.0000 | G_loss: 31.1837
# Iter 300 | D_loss: 0.0000 | G_loss: 18.2386
# ...
# Iter 800 | D_loss: 0.0000 | G_loss: 43.7635
# Iter 900 | D_loss: 0.0000 | G_loss: 43.5343
# Epoch 468
# Iter 0 | D_loss: 0.0000 | G_loss: 43.8104
# Iter 100 | D_loss: 0.0000 | G_loss: 41.4582
# Iter 200 | D_loss: 0.0000 | G_loss: 44.7468
# Iter 300 | D_loss: 0.0000 | G_loss: 42.0156
# Iter 400 | D_loss: 0.0000 | G_loss: 45.1281
# Iter 500 | D_loss: 0.0000 | G_loss: 44.1138
# Iter 600 | D_loss: 0.0000 | G_loss: 43.7162
# Iter 700 | D_loss: 0.0000 | G_loss: 43.1498
# Iter 800 | D_loss: 0.0000 | G_loss: 40.2193
# Iter 900 | D_loss: 0.0000 | G_loss: 39.8703
# Epoch 469
# Iter 0 | D_loss: 0.0000 | G_loss: 38.1835
# Iter 100 | D_loss: 0.0000 | G_loss: 39.8613
# Iter 200 | D_loss: 0.0000 | G_loss: 39.8952
# Iter 300 | D_loss: 0.0000 | G_loss: 38.7902
# Iter 400 | D_loss: 0.0000 | G_loss: 37.4309
# Iter 500 | D_loss: 0.0000 | G_loss: 34.6871
# Iter 600 | D_loss: 0.0000 | G_loss: 37.9143
# Iter 700 | D_loss: 0.0000 | G_loss: 35.6000
# Iter 800 | D_loss: 0.0000 | G_loss: 32.4422
# Iter 900 | D_loss: 0.0000 | G_loss: 33.2964
# Epoch 470
# Iter 0 | D_loss: 0.0000 | G_loss: 32.7990
# Iter 100 | D_loss: 0.0000 | G_loss: 33.6977
# Iter 200 | D_loss: 0.0000 | G_loss: 31.0898
# Iter 300 | D_loss: 0.0000 | G_loss: 30.1671
# Iter 400 | D_loss: 0.0000 | G_loss: 29.0351
# Iter 500 | D_loss: 0.0000 | G_loss: 31.0279
# Iter 600 | D_loss: 0.0000 | G_loss: 30.4518
# Iter 700 | D_loss: 0.0000 | G_loss: 29.8454
# Iter 800 | D_loss: 0.0000 | G_loss: 29.7328
# Iter 900 | D_loss: 0.0000 | G_loss: 30.2805
# Epoch 471
# Iter 0 | D_loss: 0.0000 | G_loss: 31.5733
# Iter 100 | D_loss: 0.0000 | G_loss: 30.5610
# Iter 200 | D_loss: 0.0000 | G_loss: 31.2524
# Iter 300 | D_loss: 0.0000 | G_loss: 31.9537
# Iter 400 | D_loss: 0.0000 | G_loss: 31.7068
# Iter 500 | D_loss: 0.0000 | G_loss: 31.0188
# Iter 600 | D_loss: 0.0000 | G_loss: 32.1033
# Iter 700 | D_loss: 0.0000 | G_loss: 30.0181
# Iter 800 | D_loss: 0.0000 | G_loss: 31.7152
# Iter 900 | D_loss: 0.0000 | G_loss: 31.2734
# Epoch 472
# Iter 0 | D_loss: 0.0000 | G_loss: 31.0354
# Iter 100 | D_loss: 0.0000 | G_loss: 32.0994
# Iter 200 | D_loss: 0.0000 | G_loss: 31.2819
# Iter 300 | D_loss: 0.0000 | G_loss: 32.2991
# Iter 400 | D_loss: 0.0000 | G_loss: 32.5147
# Iter 500 | D_loss: 0.0000 | G_loss: 32.1735
# Iter 600 | D_loss: 0.0000 | G_loss: 31.1821
# Iter 700 | D_loss: 0.0000 | G_loss: 30.5531
# Iter 800 | D_loss: 0.0000 | G_loss: 30.4952
# Iter 900 | D_loss: 0.0000 | G_loss: 32.1309
# Epoch 473
# Iter 0 | D_loss: 0.0000 | G_loss: 32.4371
# Iter 100 | D_loss: 0.0000 | G_loss: 31.6728
# Iter 200 | D_loss: 0.0000 | G_loss: 31.4503
# Iter 300 | D_loss: 0.0000 | G_loss: 31.8919
# Iter 400 | D_loss: 0.0000 | G_loss: 31.4337
# Iter 500 | D_loss: 0.0000 | G_loss: 31.6304
# Iter 600 | D_loss: 0.0000 | G_loss: 32.7909
# Iter 700 | D_loss: 0.0000 | G_loss: 32.2050
# Iter 800 | D_loss: 0.0000 | G_loss: 31.5718
# Iter 900 | D_loss: 0.0000 | G_loss: 32.1663
# Epoch 474
# Iter 0 | D_loss: 0.0000 | G_loss: 31.4438
# Iter 100 | D_loss: 0.0000 | G_loss: 30.5963
# Iter 200 | D_loss: 0.0000 | G_loss: 30.2920
# Iter 300 | D_loss: 0.0000 | G_loss: 32.2116
# Iter 400 | D_loss: 0.0000 | G_loss: 31.0511
# Iter 500 | D_loss: 0.0000 | G_loss: 32.2799
# Iter 600 | D_loss: 0.0000 | G_loss: 32.4228
# Iter 700 | D_loss: 0.0000 | G_loss: 32.2488
# Iter 800 | D_loss: 0.0000 | G_loss: 30.2466
# Iter 900 | D_loss: 0.0000 | G_loss: 32.7658
# Epoch 475
# Iter 0 | D_loss: 0.0000 | G_loss: 31.9517
# Iter 100 | D_loss: 0.0000 | G_loss: 32.4139
# Iter 200 | D_loss: 0.0000 | G_loss: 32.0949
# Iter 300 | D_loss: 0.0000 | G_loss: 32.1833
# Iter 400 | D_loss: 0.0000 | G_loss: 32.4365
# Iter 500 | D_loss: 0.0000 | G_loss: 32.3731
# Iter 600 | D_loss: 0.0000 | G_loss: 32.6212
# Iter 700 | D_loss: 0.0000 | G_loss: 31.6302
# Iter 800 | D_loss: 0.0000 | G_loss: 33.5039
# Iter 900 | D_loss: 0.0000 | G_loss: 31.3122
# Epoch 476
# Iter 0 | D_loss: 0.0000 | G_loss: 32.0748
# Iter 100 | D_loss: 0.0000 | G_loss: 31.8646
# Iter 200 | D_loss: 0.0000 | G_loss: 30.8884
# Iter 300 | D_loss: 0.0000 | G_loss: 32.7704
# Iter 400 | D_loss: 0.0000 | G_loss: 32.7803
# Iter 500 | D_loss: 0.0000 | G_loss: 32.1471
# Iter 600 | D_loss: 0.0000 | G_loss: 31.1558
# Iter 700 | D_loss: 0.0000 | G_loss: 31.3148
# Iter 800 | D_loss: 0.0000 | G_loss: 31.0676
# Iter 900 | D_loss: 0.0000 | G_loss: 32.3310
# Epoch 477
# Iter 0 | D_loss: 0.0000 | G_loss: 31.8637
# Iter 100 | D_loss: 0.0000 | G_loss: 32.9709
# Iter 200 | D_loss: 0.0000 | G_loss: 31.1576
# Iter 300 | D_loss: 0.0000 | G_loss: 32.2115
# Iter 400 | D_loss: 0.0000 | G_loss: 31.5886
# Iter 500 | D_loss: 0.0000 | G_loss: 32.5630
# Iter 600 | D_loss: 0.0000 | G_loss: 31.3093
# Iter 700 | D_loss: 0.0000 | G_loss: 31.8530
# Iter 800 | D_loss: 0.0000 | G_loss: 31.9967
# Iter 900 | D_loss: 0.0000 | G_loss: 32.6837
# Epoch 478
# Iter 0 | D_loss: 0.0000 | G_loss: 31.6933
# Iter 100 | D_loss: 0.0000 | G_loss: 33.6567
# Iter 200 | D_loss: 0.0000 | G_loss: 32.7983
# Iter 300 | D_loss: 0.0000 | G_loss: 32.4971
# Iter 400 | D_loss: 0.0000 | G_loss: 32.6502
# Iter 500 | D_loss: 0.0000 | G_loss: 26.0957
# Iter 600 | D_loss: 0.0000 | G_loss: 27.8427
# Iter 700 | D_loss: 0.0000 | G_loss: 28.8367
# Iter 800 | D_loss: 0.0000 | G_loss: 27.2522
# Iter 900 | D_loss: 0.0000 | G_loss: 28.1419
# Epoch 479
# Iter 0 | D_loss: 0.0000 | G_loss: 29.4666
# Iter 100 | D_loss: 0.0000 | G_loss: 29.4159
# Iter 200 | D_loss: 0.0000 | G_loss: 29.1772
# Iter 300 | D_loss: 0.0000 | G_loss: 30.3431
# Iter 400 | D_loss: 0.0000 | G_loss: 30.1497
# Iter 500 | D_loss: 0.0000 | G_loss: 28.8246
# Iter 600 | D_loss: 0.0000 | G_loss: 29.9947
# Iter 700 | D_loss: 0.0000 | G_loss: 28.4086
# Iter 800 | D_loss: 0.0000 | G_loss: 28.9895
# Iter 900 | D_loss: 0.0000 | G_loss: 29.8267
# Epoch 480
# Iter 0 | D_loss: 0.0000 | G_loss: 29.9215
# Iter 100 | D_loss: 0.0000 | G_loss: 28.9175
# Iter 200 | D_loss: 0.0000 | G_loss: 30.7083
# Iter 300 | D_loss: 0.0000 | G_loss: 29.9015
# Iter 400 | D_loss: 0.0000 | G_loss: 30.2584
# Iter 500 | D_loss: 0.0000 | G_loss: 28.0851
# Iter 600 | D_loss: 0.0000 | G_loss: 29.2417
# Iter 700 | D_loss: 0.0000 | G_loss: 28.6132
# Iter 800 | D_loss: 0.0000 | G_loss: 30.3658
# Iter 900 | D_loss: 0.0000 | G_loss: 30.3132
# Epoch 481
# Iter 0 | D_loss: 0.0000 | G_loss: 30.5108
# Iter 100 | D_loss: 0.0000 | G_loss: 27.7428
# Iter 200 | D_loss: 0.0000 | G_loss: 29.8547
# Iter 300 | D_loss: 0.0000 | G_loss: 29.7593
# Iter 400 | D_loss: 0.0000 | G_loss: 29.5753
# Iter 500 | D_loss: 0.0000 | G_loss: 29.4284
# Iter 600 | D_loss: 0.0000 | G_loss: 58.0586
# Iter 700 | D_loss: 0.0000 | G_loss: 26.9774
# Iter 800 | D_loss: 0.0000 | G_loss: 28.5517
# Iter 900 | D_loss: 0.0000 | G_loss: 29.7668
# Epoch 482
# Iter 0 | D_loss: 0.0000 | G_loss: 29.6897
# Iter 100 | D_loss: 0.0000 | G_loss: 29.1189
# Iter 200 | D_loss: 0.0000 | G_loss: 28.1060
# Iter 300 | D_loss: 0.0000 | G_loss: 26.9604
# Iter 400 | D_loss: 0.0000 | G_loss: 27.0670
# Iter 500 | D_loss: 0.0000 | G_loss: 27.1625
# Iter 600 | D_loss: 0.0000 | G_loss: 28.1459
# Iter 700 | D_loss: 0.0000 | G_loss: 28.9897
# Iter 800 | D_loss: 0.0000 | G_loss: 25.6653
# Iter 900 | D_loss: 0.0000 | G_loss: 27.1888
# Epoch 483
# Iter 0 | D_loss: 0.0000 | G_loss: 26.4215
# Iter 100 | D_loss: 0.0000 | G_loss: 25.8767
# Iter 200 | D_loss: 0.0000 | G_loss: 25.9254
# Iter 300 | D_loss: 0.0000 | G_loss: 27.1981
# Iter 400 | D_loss: 0.0000 | G_loss: 25.5706
# Iter 500 | D_loss: 0.0000 | G_loss: 26.0768
# Iter 600 | D_loss: 0.0000 | G_loss: 25.4542
# Iter 700 | D_loss: 0.0000 | G_loss: 24.2444
# Iter 800 | D_loss: 0.0000 | G_loss: 21.5150
# Iter 900 | D_loss: 0.0000 | G_loss: 23.4583
# Epoch 484
# Iter 0 | D_loss: 0.0000 | G_loss: 23.7845
# Iter 100 | D_loss: 0.0000 | G_loss: 23.2121
# Iter 200 | D_loss: 0.0000 | G_loss: 23.4441
# Iter 300 | D_loss: 0.0000 | G_loss: 23.5648
# Iter 400 | D_loss: 0.0000 | G_loss: 42.7562
# Iter 500 | D_loss: 0.0000 | G_loss: 35.1107
# Iter 600 | D_loss: 0.0000 | G_loss: 31.6421
# Iter 700 | D_loss: 0.0000 | G_loss: 22.0646
# Iter 800 | D_loss: 0.0000 | G_loss: 38.7174
# Iter 900 | D_loss: 0.0000 | G_loss: 37.5986
# Epoch 485
# Iter 0 | D_loss: 0.0000 | G_loss: 28.6312
# Iter 100 | D_loss: 0.0000 | G_loss: 27.4025
# Iter 200 | D_loss: 0.0000 | G_loss: 22.0760
# Iter 300 | D_loss: 0.0000 | G_loss: 23.3030
# Iter 400 | D_loss: 0.0000 | G_loss: 21.1614
# Iter 500 | D_loss: 0.0000 | G_loss: 21.3931
# Iter 600 | D_loss: 0.0000 | G_loss: 21.7620
# Iter 700 | D_loss: 0.0000 | G_loss: 18.2978
# Iter 800 | D_loss: 0.0000 | G_loss: 19.2434
# Iter 900 | D_loss: 0.0000 | G_loss: 19.9055
# Epoch 486
# Iter 0 | D_loss: 0.0000 | G_loss: 19.9558
# Iter 100 | D_loss: 0.0000 | G_loss: 60.3901
# Iter 200 | D_loss: 0.0000 | G_loss: 59.4216
# Iter 300 | D_loss: 0.0000 | G_loss: 57.5514
# Iter 400 | D_loss: 0.0000 | G_loss: 57.5583
# Iter 500 | D_loss: 0.0000 | G_loss: 55.1252
# Iter 600 | D_loss: 0.0000 | G_loss: 55.6263
# Iter 700 | D_loss: 0.0000 | G_loss: 52.7024
# Iter 800 | D_loss: 0.0000 | G_loss: 45.8542
# Iter 900 | D_loss: 0.0000 | G_loss: 44.5824
# Epoch 487
# Iter 0 | D_loss: 0.0000 | G_loss: 44.4045
# Iter 100 | D_loss: 0.0000 | G_loss: 43.5402
# Iter 200 | D_loss: 0.0000 | G_loss: 42.5119
# Iter 300 | D_loss: 0.0000 | G_loss: 43.4211
# Iter 400 | D_loss: 0.0000 | G_loss: 41.0902
# Iter 500 | D_loss: 0.0000 | G_loss: 40.5761
# Iter 600 | D_loss: 0.0000 | G_loss: 38.8480
# Iter 700 | D_loss: 0.0000 | G_loss: 38.2242
# Iter 800 | D_loss: 0.0000 | G_loss: 37.7094
# Iter 900 | D_loss: 0.0000 | G_loss: 36.2050
# Epoch 488
# Iter 0 | D_loss: 0.0000 | G_loss: 36.4833
# Iter 100 | D_loss: 0.0000 | G_loss: 36.7105
# Iter 200 | D_loss: 0.0000 | G_loss: 37.2165
# Iter 300 | D_loss: 0.0000 | G_loss: 37.2527
# Iter 400 | D_loss: 0.0000 | G_loss: 35.4873
# Iter 500 | D_loss: 0.0000 | G_loss: 35.4980
# Iter 600 | D_loss: 0.0000 | G_loss: 35.6598
# Iter 700 | D_loss: 0.0000 | G_loss: 33.5937
# Iter 800 | D_loss: 0.0000 | G_loss: 34.1039
# Iter 900 | D_loss: 0.0000 | G_loss: 34.9995
# Epoch 489
# Iter 0 | D_loss: 0.0000 | G_loss: 34.0892
# Iter 100 | D_loss: 0.0000 | G_loss: 34.0769
# Iter 200 | D_loss: 0.0000 | G_loss: 34.1452
# Iter 300 | D_loss: 0.0000 | G_loss: 31.8523
# Iter 400 | D_loss: 0.0000 | G_loss: 28.6418
# Iter 500 | D_loss: 0.0000 | G_loss: 25.1213
# Iter 600 | D_loss: 0.0000 | G_loss: 24.9964
# Iter 700 | D_loss: 0.0000 | G_loss: 25.8100
# Iter 800 | D_loss: 0.0000 | G_loss: 24.9899
# Iter 900 | D_loss: 0.0000 | G_loss: 25.7617
# Epoch 490
# Iter 0 | D_loss: 0.0000 | G_loss: 25.2162
# Iter 100 | D_loss: 0.0000 | G_loss: 25.7981
# Iter 200 | D_loss: 0.0000 | G_loss: 25.7094
# Iter 300 | D_loss: 0.0000 | G_loss: 25.0342
# Iter 400 | D_loss: 0.0000 | G_loss: 25.7110
# Iter 500 | D_loss: 0.0000 | G_loss: 25.6132
# Iter 600 | D_loss: 0.0000 | G_loss: 25.4836
# Iter 700 | D_loss: 0.0000 | G_loss: 25.1031
# Iter 800 | D_loss: 0.0000 | G_loss: 25.4180
# Iter 900 | D_loss: 0.0000 | G_loss: 25.9125
# Epoch 491
# Iter 0 | D_loss: 0.0000 | G_loss: 26.0008
# Iter 100 | D_loss: 0.0000 | G_loss: 26.4355
# Iter 200 | D_loss: 0.0000 | G_loss: 25.6940
# Iter 300 | D_loss: 0.0000 | G_loss: 26.2982
# Iter 400 | D_loss: 0.0000 | G_loss: 26.3757
# Iter 500 | D_loss: 0.0000 | G_loss: 24.3950
# Iter 600 | D_loss: 0.0000 | G_loss: 25.0623
# Iter 700 | D_loss: 0.0000 | G_loss: 26.0906
# Iter 800 | D_loss: 0.0000 | G_loss: 24.9763
# Iter 900 | D_loss: 0.0000 | G_loss: 49.4649
# Epoch 492
# Iter 0 | D_loss: 0.0000 | G_loss: 43.4489
# Iter 100 | D_loss: 0.0000 | G_loss: 37.8373
# Iter 200 | D_loss: 0.0000 | G_loss: 37.7765
# Iter 300 | D_loss: 0.0000 | G_loss: 37.8876
# Iter 400 | D_loss: 0.0000 | G_loss: 37.6960
# Iter 500 | D_loss: 0.0000 | G_loss: 36.3472
# Iter 600 | D_loss: 0.0000 | G_loss: 35.7298
# Iter 700 | D_loss: 0.0000 | G_loss: 34.5845
# Iter 800 | D_loss: 0.0000 | G_loss: 34.7302
# Iter 900 | D_loss: 0.0000 | G_loss: 31.8321
# Epoch 493
# Iter 0 | D_loss: 0.0000 | G_loss: 32.1536
# Iter 100 | D_loss: 0.0000 | G_loss: 32.7700
# Iter 200 | D_loss: 0.0000 | G_loss: 31.1375
# Iter 300 | D_loss: 0.0000 | G_loss: 31.0673
# Iter 400 | D_loss: 0.0000 | G_loss: 32.5434
# Iter 500 | D_loss: 0.0000 | G_loss: 32.3524
# Iter 600 | D_loss: 0.0000 | G_loss: 29.8310
# Iter 700 | D_loss: 0.0000 | G_loss: 27.1854
# Iter 800 | D_loss: 0.0000 | G_loss: 25.0778
# Iter 900 | D_loss: 0.0000 | G_loss: 27.0001
# Epoch 494
# Iter 0 | D_loss: 0.0000 | G_loss: 26.1626
# Iter 100 | D_loss: 0.0000 | G_loss: 27.2491
# Iter 200 | D_loss: 0.0000 | G_loss: 26.0400
# Iter 300 | D_loss: 0.0000 | G_loss: 24.9896
# Iter 400 | D_loss: 0.0000 | G_loss: 24.8056
# Iter 500 | D_loss: 0.0000 | G_loss: 25.2657
# Iter 600 | D_loss: 0.0000 | G_loss: 23.4255
# Iter 700 | D_loss: 0.0000 | G_loss: 22.6444
# Iter 800 | D_loss: 0.0000 | G_loss: 23.3842
# Iter 900 | D_loss: 0.0000 | G_loss: 24.5277
# Epoch 495
# Iter 0 | D_loss: 0.0000 | G_loss: 23.5738
# Iter 100 | D_loss: 0.0000 | G_loss: 23.7670
# Iter 200 | D_loss: 0.0000 | G_loss: 24.6049
# Iter 300 | D_loss: 0.0000 | G_loss: 23.6523
# Iter 400 | D_loss: 0.0000 | G_loss: 24.4880
# Iter 500 | D_loss: 0.0000 | G_loss: 23.3779
# Iter 600 | D_loss: 0.0000 | G_loss: 24.5121
# Iter 700 | D_loss: 0.0000 | G_loss: 25.0957
# Iter 800 | D_loss: 0.0000 | G_loss: 25.9684
# Iter 900 | D_loss: 0.0000 | G_loss: 25.8342
# Epoch 496
# Iter 0 | D_loss: 0.0000 | G_loss: 26.0762
# Iter 100 | D_loss: 0.0000 | G_loss: 26.4338
# Iter 200 | D_loss: 0.0000 | G_loss: 26.7856
# Iter 300 | D_loss: 0.0000 | G_loss: 25.1035
# Iter 400 | D_loss: 0.0000 | G_loss: 25.7528
# Iter 500 | D_loss: 0.0000 | G_loss: 26.8280
# Iter 600 | D_loss: 0.0000 | G_loss: 25.0111
# Iter 700 | D_loss: 0.0000 | G_loss: 25.9746
# Iter 800 | D_loss: 0.0000 | G_loss: 25.7679
# Iter 900 | D_loss: 0.0000 | G_loss: 25.3088
# Epoch 497
# Iter 0 | D_loss: 0.0000 | G_loss: 25.8467
# Iter 100 | D_loss: 0.0000 | G_loss: 24.6389
# Iter 200 | D_loss: 0.0000 | G_loss: 26.0148
# Iter 300 | D_loss: 0.0000 | G_loss: 25.8610
# Iter 400 | D_loss: 0.0000 | G_loss: 25.7299
# Iter 500 | D_loss: 0.0000 | G_loss: 26.0668
# Iter 600 | D_loss: 0.0000 | G_loss: 26.0096
# Iter 700 | D_loss: 0.0000 | G_loss: 25.8540
# Iter 800 | D_loss: 0.0000 | G_loss: 25.7914
# Iter 900 | D_loss: 0.0000 | G_loss: 25.6939
# Epoch 498
# Iter 0 | D_loss: 0.0000 | G_loss: 26.9474
# Iter 100 | D_loss: 0.0000 | G_loss: 22.6906
# Iter 200 | D_loss: 0.0000 | G_loss: 23.7570
# Iter 300 | D_loss: 0.0000 | G_loss: 22.4841
# Iter 400 | D_loss: 0.0000 | G_loss: 22.1096
# Iter 500 | D_loss: 0.0000 | G_loss: 24.1610
# Iter 600 | D_loss: 0.0000 | G_loss: 24.0093
# Iter 700 | D_loss: 0.0000 | G_loss: 24.0550
# Iter 800 | D_loss: 0.0000 | G_loss: 24.0174
# Iter 900 | D_loss: 0.0000 | G_loss: 24.6797
# Epoch 499
# Iter 0 | D_loss: 0.0000 | G_loss: 24.6188
# Iter 100 | D_loss: 0.0000 | G_loss: 23.4403
# Iter 200 | D_loss: 0.0000 | G_loss: 23.6050
# Iter 300 | D_loss: 0.0000 | G_loss: 23.8873
# Iter 400 | D_loss: 0.0000 | G_loss: 24.2379
# Iter 500 | D_loss: 0.0000 | G_loss: 24.0182
# Iter 600 | D_loss: 0.0000 | G_loss: 24.4738
# Iter 700 | D_loss: 0.0000 | G_loss: 24.3805
# Iter 800 | D_loss: 0.0000 | G_loss: 24.0757
# Iter 900 | D_loss: 0.0000 | G_loss: 24.7001
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : Task3-20260416-231514
# COMET INFO:     url                   : https://www.comet.com/drmrai/d7047e-lab2/0609616dbcfc4a10b9c43c00ab9cdb2e
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     D_loss_epoch [500] : (9.374169573214167e-17, 0.0290418443570819)
# COMET INFO:     D_loss_fake [500]  : (0.0, 0.010070993787665695)
# COMET INFO:     D_loss_real [500]  : (5.929873993208679e-23, 0.01897085056211695)
# COMET INFO:     G_loss_epoch [500] : (7.202854376846851, 104.19350298186376)
# COMET INFO:     loss [93700]       : (0.0, 250.60848999023438)
# COMET INFO:   Others:
# COMET INFO:     Name : Task3-20260416-231514
# COMET INFO:   Parameters:
# COMET INFO:     Z_dim         : 100
# COMET INFO:     batch_size    : 64
# COMET INFO:     epochs        : 500
# COMET INFO:     h_dim         : 256
# COMET INFO:     learning_rate : 0.001
# COMET INFO:     loss_function : nn.binary_cross_entropy_with_logits
# COMET INFO:     optimizer     : Adam
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
for d in range(10):
    z = torch.randn(1, Z_dim).to(device)
    c = torch.zeros(1, y_dim).to(device)
    c[0, d] = 1

    img = G(z, c).detach().cpu().view(28,28)
    plt.imshow(img, cmap="gray")
    plt.title(f"Digit {d}")
    plt.show()

# %%
import os

os.makedirs("generated_digits", exist_ok=True)

for d in range(10):
    z = torch.randn(1, Z_dim).to(device)
    c = torch.zeros(1, y_dim).to(device)
    c[0, d] = 1

    img = G(z, c).detach().cpu().view(28, 28)

    plt.figure()
    plt.imshow(img, cmap="gray")
    plt.title(f"Digit {d}")
    plt.axis("off")

    plt.savefig(f"generated_digits/digit_{d}.png")
    plt.close()
