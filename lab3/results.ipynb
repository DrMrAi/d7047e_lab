# %%
Från home/jovyan/lab3/additive-20260510-204034.pt med gamla valsettet:
Här hade vi nedåtgående validation loss pga token mismatch train/val:
Device: cuda
BLEU:
BLEU-1: 0.09907188007088204
BLEU-2: 0.043116968804210364
BLEU-3: 0.01697075034931747
BLEU-4: 0.006085401699063256

METEOR:
0.14595404131401035

ROUGE:
ROUGE-1: 0.1441041181808909
ROUGE-2: 0.03846218398498193
ROUGE-L: 0.13907405044200666

CIDEr:
0.003536052792079731

# %%
home/jovyan/lab3/additive-20260510-214410.pt med nya valsettet:
    BLEU:
BLEU-1: 0.10560690163413497
BLEU-2: 0.04529279590526016
BLEU-3: 0.0183831628244305
BLEU-4: 0.00700048118601553

METEOR:
0.1513492536058591

ROUGE:
ROUGE-1: 0.15522453645390819
ROUGE-2: 0.037818476835731266
ROUGE-L: 0.15203084817069892

CIDEr:
0.0013755491807414255

# %%
Alla modeller upp till detta tillfället overfittade efter 2 epoker. Vi testade detta genom att evaluera modellen
efter varje 100de steg. Det gav resultatet vi har i spiritual_corolla_58 med en jämn nedgång.

# %%
/home/jovyan/lab3/additive-upgraded-20260511-002625.pt
BLEU:
BLEU-1: 0.12866471823910863
BLEU-2: 0.06991054196010604
BLEU-3: 0.03565613231215902
BLEU-4: 0.01662799449569685

METEOR:
0.18681721034078294

ROUGE:
ROUGE-1: 0.20288601894063624
ROUGE-2: 0.06903209605992454
ROUGE-L: 0.2011700842977352

CIDEr:
0.024477292350488556

# %%
home/jovyan/lab3/additive-upgraded-20260511-013903.pt den med 100 epoker
BLEU:
BLEU-1: 0.16582470940212862
BLEU-2: 0.0761279540637551
BLEU-3: 0.03358039768532648
BLEU-4: 0.013446810583764577

METEOR:
0.11799754548239225

ROUGE:
ROUGE-1: 0.20698606738342792
ROUGE-2: 0.04099880658508149
ROUGE-L: 0.2058392825016429

CIDEr:
0.0331102705829642

# %% [markdown]
# Evalueringskriptet har varit fel tills nu...
# "lstm_out, _ = model.lstm(cap_emb)" ska vara "lstm_out, hidden = model.lstm(cap_emb)" osv osv.
# home/jovyan/lab3/additive-upgraded-20260511-125646.pt
# BLEU:
# BLEU-1: 0.5820454211839705
# BLEU-2: 0.3935333600712487
# BLEU-3: 0.25876084789441806
# BLEU-4: 0.16814209973383532
#
# METEOR:
# 0.3795796427870379
#
# ROUGE:
# ROUGE-1: 0.5111364334008257
# ROUGE-2: 0.2494626956858884
# ROUGE-L: 0.47184928835519224
#
# CIDEr:
# 0.4820470389483955

# %%
home/jovyan/lab3/additive-upgraded-20260511-013903.pt den med 100 epoker
BLEU:
BLEU-1: 0.5566898081584029
BLEU-2: 0.36622378488558394
BLEU-3: 0.23554718168578054
BLEU-4: 0.1497420428613171

METEOR:
0.36487951280882014

ROUGE:
ROUGE-1: 0.49422691604565444
ROUGE-2: 0.23096227356561172
ROUGE-L: 0.45584813106684535

CIDEr:
0.4446301950351274

# %%
home/jovyan/lab3/attention-hidden-inject-20260511-141425.pt attention å så
Computing BLEU...
  BLEU-1: 0.5970
  BLEU-2: 0.4092
  BLEU-3: 0.2719
  BLEU-4: 0.1765

Computing METEOR...
  METEOR: 0.3925

Computing ROUGE...
  ROUGE-1: 0.5219
  ROUGE-2: 0.2618
  ROUGE-L: 0.4841

Computing CIDEr...
  CIDEr: 0.5317

══ Evaluation Summary ══
  BLEU-1:  0.5970
  BLEU-2:  0.4092
  BLEU-3:  0.2719
  BLEU-4:  0.1765
  METEOR:  0.3925
  ROUGE-1: 0.5219
  ROUGE-2: 0.2618
  ROUGE-L: 0.4841
  CIDEr:   0.5317
